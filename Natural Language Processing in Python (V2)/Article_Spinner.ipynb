# %%
# https://www.kaggle.com/shivamkushwaha/bbc-full-text-document-classification
# !wget -nc https://lazyprogrammer.me/course_files/nlp/bbc_text_cls.csv
# Out:
# --2024-06-11 19:26:55--  https://lazyprogrammer.me/course_files/nlp/bbc_text_cls.csv
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 104.21.23.210, 172.67.213.166, 2606:4700:3031::6815:17d2, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|104.21.23.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5085081 (4.8M) [text/csv]
# Saving to: ‘bbc_text_cls.csv’
#
# bbc_text_cls.csv    100%[===================>]   4.85M  --.-KB/s    in 0.1s
#
# 2024-06-11 19:26:55 (42.9 MB/s) - ‘bbc_text_cls.csv’ saved [5085081/5085081]

# %%
import numpy as np
import pandas as pd
import textwrap
import nltk
from nltk import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df = pd.read_csv("bbc_text_cls.csv")

# %%
df.head()
# Out:
#                                                 text    labels
# 0  Ad sales boost Time Warner profit\n\nQuarterly...  business
# 1  Dollar gains on Greenspan speech\n\nThe dollar...  business
# 2  Yukos unit buyer faces loan claim\n\nThe owner...  business
# 3  High fuel prices hit BA's profits\n\nBritish A...  business
# 4  Pernod takeover talk lifts Domecq\n\nShares in...  business

# %%
labels = set(df["labels"])
labels
# Out:
# {'business', 'entertainment', 'politics', 'sport', 'tech'}

# %%
# Pick a label to train
label = "entertainment"

# %%
texts = df[df["labels"] == label]["text"]
texts.head()
# Out:
# 510    Gallery unveils interactive tree\n\nA Christma...
# 511    Jarre joins fairytale celebration\n\nFrench mu...
# 512    Musical treatment for Capra film\n\nThe classi...
# 513    Richard and Judy choose top books\n\nThe 10 au...
# 514    Poppins musical gets flying start\n\nThe stage...
# Name: text, dtype: object

# %%
texts[510]
# Out:
# 'Gallery unveils interactive tree\n\nA Christmas tree that can receive text messages has been unveiled at London\'s Tate Britain art gallery.\n\nThe spruce has an antenna which can receive Bluetooth texts sent by visitors to the Tate. The messages will be "unwrapped" by sculptor Richard Wentworth, who is responsible for decorating the tree with broken plates and light bulbs. It is the 17th year that the gallery has invited an artist to dress their Christmas tree. Artists who have decorated the Tate tree in previous years include Tracey Emin in 2002.\n\nThe plain green Norway spruce is displayed in the gallery\'s foyer. Its light bulb adornments are dimmed, ordinary domestic ones joined together with string. The plates decorating the branches will be auctioned off for the children\'s charity ArtWorks. Wentworth worked as an assistant to sculptor Henry Moore in the late 1960s. His reputation as a sculptor grew in the 1980s, while he has been one of the most influential teachers during the last two decades. Wentworth is also known for his photography of mundane, everyday subjects such as a cigarette packet jammed under the wonky leg of a table.'

# %%
# collect counts
probs = {} # key: (w(t-1), w(t+1)), value: {w(t): count(w(t))}

for doc in texts:
  lines = doc.split("\n")
  for line in lines:
    tokens = word_tokenize(line)
    for i in range(len(tokens) - 2):
      t_0 = tokens[i]
      t_1 = tokens[i+1]
      t_2 = tokens[i+2]
      key = (t_0, t_2)
      if key not in probs:
        probs[key] = {}

      # add count for middle token
      if t_1 not in probs[key]:
        probs[key][t_1] = 1
      else:
        probs[key][t_1] += 1

# %%
probs
# Out:
# {('Gallery', 'interactive'): {'unveils': 1},
#  ('unveils', 'tree'): {'interactive': 1},
#  ('A', 'tree'): {'Christmas': 1},
#  ('Christmas', 'that'): {'tree': 1},
#  ('tree', 'can'): {'that': 1},
#  ('that', 'receive'): {'can': 1},
#  ('can', 'text'): {'receive': 1},
#  ('receive', 'messages'): {'text': 1},
#  ('text', 'has'): {'messages': 1},
#  ('messages', 'been'): {'has': 1},
#  ('has', 'unveiled'): {'been': 1},
#  ('been', 'at'): {'unveiled': 1,
#   'shown': 1,
#   'estimated': 1,
#   'difficult': 1,
#   'surprised': 1,
#   'announced': 1,
#   'honoured': 2},
#  ('unveiled', 'London'): {'at': 1},
#  ('at', "'s"): {'London': 11,
#   'Versace': 1,
#   'Sotheby': 1,
#   'Sunday': 4,
#   'Hollywood': 2,
#   'Grauman': 1,
#   'Israel': 2,
#   'Glasgow': 1,
#   'Scotland': 2,
#   'Dublin': 1,
#   'Guernsey': 1,
#   'MTV': 1,
#   'Oxfam': 1,
#   'France': 1,
#   'Wednesday': 1,
#   '1985': 1,
#   'Sadler': 2,
#   'Toronto': 1,
#   'Bristol': 1,
#   'June': 1},
#  ('London', 'Tate'): {"'s": 1},
#  ("'s", 'Britain'): {'Tate': 1},
#  ('Tate', 'art'): {'Britain': 1},
#  ('Britain', 'gallery'): {'art': 1},
#  ('art', '.'): {'gallery': 1, 'colleges': 1},
#  ('The', 'has'): {'spruce': 1,
#   'book': 2,
#   'exhibition': 1,
#   'film': 7,
#   'Aviator': 7,
#   'Fockers': 1,
#   'star': 1,
#   'school': 1,
#   'government': 2,
#   '64-year-old': 1,
#   'process': 1,
#   'track': 1,
#   'UK': 2,
#   'show': 2,
#   'programme': 1,
#   'BBC': 2,
#   'Guardian': 1,
#   'band': 1,
#   'Brits': 2,
#   'US': 2,
#   'Producers': 1,
#   'decision': 1,
#   'ceremony': 1,
#   'Baftas': 1,
#   'Louvre': 1},
#  ('spruce', 'an'): {'has': 1},
#  ('has', 'antenna'): {'an': 1},
#  ('an', 'which'): {'antenna': 1, 'aria': 1},
#  ('antenna', 'can'): {'which': 1},
#  ('which', 'receive'): {'can': 1},
#  ('can', 'Bluetooth'): {'receive': 1},
#  ('receive', 'texts'): {'Bluetooth': 1},
#  ('Bluetooth', 'sent'): {'texts': 1},
#  ('texts', 'by'): {'sent': 1},
#  ('sent', 'visitors'): {'by': 1},
#  ('by', 'to'): {'visitors': 1, 'trying': 1, '600,000': 1, 'midnight': 1},
#  ('visitors', 'the'): {'to': 1, 'made': 1, 'through': 1},
#  ('to', 'Tate'): {'the': 1},
#  ('the', '.'): {'Tate': 1,
#   'festivities': 1,
#   'UK': 12,
#   'judges': 2,
#   'World': 2,
#   'award': 4,
#   'Church': 1,
#   'Bishop': 1,
#   'BBC': 6,
#   'country': 2,
#   'back': 2,
#   'sale': 1,
#   'Whitbread': 1,
#   'Year': 1,
#   'shortlist': 1,
#   'artists': 2,
#   'show': 18,
#   'west': 1,
#   'ground': 2,
#   'discipline': 1,
#   'future': 6,
#   'years': 2,
#   'problem': 1,
#   'world': 15,
#   'censors': 1,
#   '1920s': 1,
#   'US': 20,
#   'series': 9,
#   'public': 5,
#   'attendance': 1,
#   'war': 2,
#   'film': 15,
#   '1980s': 2,
#   'mind': 1,
#   'cinema': 1,
#   'book': 2,
#   'deadline': 1,
#   'industry': 3,
#   'movie': 3,
#   '1600s': 1,
#   'campaign': 2,
#   'project': 5,
#   'night': 7,
#   'Oscars': 9,
#   'festival': 5,
#   'eulogy': 2,
#   'chart': 1,
#   'King': 2,
#   'year': 9,
#   'internet': 1,
#   'Sun': 1,
#   'firm': 1,
#   'injuries': 1,
#   'ceremony': 11,
#   'camera': 2,
#   'scenes': 1,
#   'bombings': 1,
#   'extras': 1,
#   'tale': 1,
#   'novel': 1,
#   'Bounty': 1,
#   'Netherlands': 1,
#   'politician': 1,
#   'bump': 1,
#   'Rings': 1,
#   'middle': 1,
#   'mainstream': 4,
#   'biopic': 1,
#   'premiere': 1,
#   'Kranks': 2,
#   'field': 2,
#   'Dead': 1,
#   'effects': 1,
#   'voters': 1,
#   'deliberations': 2,
#   'count': 1,
#   'outsider': 2,
#   'event': 9,
#   'Waterfront': 1,
#   'Festival': 1,
#   'books': 1,
#   'studio': 2,
#   'Killers': 2,
#   'concert': 1,
#   'poll': 1,
#   'case': 3,
#   'head': 1,
#   'cover': 1,
#   'CD': 1,
#   'charges': 2,
#   'shows': 1,
#   'spokesman': 1,
#   'track': 1,
#   'cancer': 1,
#   'legend': 1,
#   '70s': 1,
#   'floor': 1,
#   'album': 1,
#   'complaint': 2,
#   'Papas': 1,
#   'top': 2,
#   'morning': 1,
#   'music': 2,
#   'masses': 1,
#   'taxpayer': 1,
#   'band': 2,
#   'DJ': 1,
#   'headliners': 1,
#   'stage': 2,
#   'Hoople': 2,
#   'burglary': 1,
#   'window': 1,
#   'Bunnymen': 2,
#   'Mic': 1,
#   'scheme': 1,
#   'issues': 1,
#   'prosecution': 1,
#   'Pops': 3,
#   'auction': 1,
#   'time': 3,
#   'Sugababes': 1,
#   'continent': 1,
#   'charity': 2,
#   'Mack': 1,
#   'bank': 2,
#   'money': 3,
#   'schedule': 1,
#   'zeitgeist': 1,
#   'stars': 2,
#   'murder': 1,
#   'ratings': 2,
#   'Atlantic': 3,
#   'suburbs': 1,
#   'originals': 2,
#   'bottom': 1,
#   'Blind': 1,
#   'stadium': 1,
#   'pipeline': 1,
#   'print': 1,
#   'tsunami': 1,
#   'site': 1,
#   'movies': 1,
#   'vote': 2,
#   'winner': 3,
#   'Olympics': 1,
#   'findings': 1,
#   'episode': 1,
#   'original': 1,
#   'agreement': 1,
#   'camp': 1,
#   'service': 1,
#   'past': 2,
#   'decision': 1,
#   'comedian': 1,
#   'truth': 1,
#   'council': 1,
#   'channel': 1,
#   'radio': 1,
#   'transmission': 1,
#   'Ugly': 1,
#   'way': 1,
#   'magazine': 1,
#   'programme': 1,
#   'house': 3,
#   'station': 1,
#   '1970s': 1,
#   'Bahamas': 1,
#   'charts': 1,
#   'Radio': 1,
#   'city': 1,
#   'crowd': 1,
#   'controversy': 1,
#   'awards': 1,
#   'disappearance': 1,
#   'truce': 1,
#   'bone': 1,
#   'Brits': 1,
#   'list': 3,
#   'boxes': 1,
#   'minute': 1,
#   'day': 1,
#   'label': 1,
#   'guitarist': 1,
#   'assault': 1,
#   'People': 1,
#   'bill': 1,
#   'documentary': 1,
#   'star': 2,
#   'hammer': 1,
#   'production': 2,
#   'set': 1,
#   'crush': 1,
#   'musical': 1,
#   'theatre': 2,
#   'hall': 1,
#   'director': 1,
#   'response': 1,
#   'smoke': 1,
#   'week': 1,
#   'community': 1,
#   'changes': 1,
#   'incident': 1,
#   'galaxy': 1,
#   'role': 2,
#   'Earth': 1,
#   'opportunity': 1,
#   'forest': 1,
#   'author': 1,
#   'byline': 1,
#   'closet': 1,
#   'Beast': 1,
#   'street': 1,
#   'f-word': 1,
#   'results': 1,
#   'MC': 1,
#   'demographic': 1,
#   'craphouse': 1,
#   'Parents': 2,
#   'Friday': 1,
#   'Beckhams': 1,
#   'Opera': 1,
#   'running': 1,
#   'moment': 1,
#   'mid-1990s': 1,
#   'Christ': 2,
#   'Academy': 1,
#   'device': 1,
#   'chase': 1,
#   'screen': 1,
#   'Annies': 1,
#   'seats': 1,
#   'weekend': 1,
#   'lead': 2,
#   'game': 1,
#   'workforce': 1,
#   'stairs': 1,
#   'same': 1,
#   'story': 1,
#   'magic': 1,
#   'short-term': 1,
#   'next': 1,
#   'throngs': 1,
#   'Baftas': 1,
#   'newspaper': 1,
#   '1960s': 1,
#   'summer': 1,
#   'crew': 1,
#   'board': 1,
#   'writers': 1,
#   'limelight': 1,
#   'publicity': 1,
#   'prize': 2,
#   'audience': 1,
#   'process': 1,
#   'boy': 1,
#   'jury': 1,
#   'Vatican': 1,
#   'Pope': 1,
#   'museum': 1},
#  ('Tate', 'The'): {'.': 1, '(': 1},
#  ('.', 'messages'): {'The': 1},
#  ('The', 'will'): {'messages': 1,
#   'role': 1,
#   'winner': 1,
#   'festival': 1,
#   'event': 2,
#   'winners': 1,
#   'Oscars': 1,
#   'awards': 3,
#   'group': 1,
#   'band': 3,
#   'cards': 1,
#   'song': 2,
#   'Mack': 1,
#   'story': 1,
#   'programme': 1,
#   'celebrities': 1,
#   'judges': 1,
#   'show': 2,
#   'musical': 1,
#   'concert': 1,
#   'ceremony': 1,
#   'music': 1,
#   'production': 1,
#   'Pixies': 1,
#   'train': 1,
#   'script': 1,
#   'Aviator': 1,
#   'film-maker': 1},
#  ('messages', 'be'): {'will': 1},
#  ('will', '``'): {'be': 2, 'play': 1},
#  ('be', 'unwrapped'): {'``': 1},
#  ('``', "''"): {'unwrapped': 1,
#   'vast': 1,
#   'fierce': 1,
#   'delighted': 2,
#   'Dirty': 1,
#   'bump': 1,
#   'hero': 1,
#   'barrier-breaking': 1,
#   'heart-wrenching': 1,
#   'non-essential': 1,
#   'Suge': 1,
#   'untrue': 1,
#   'LA': 1,
#   'resting': 1,
#   'determined': 1,
#   'sing-along': 1,
#   'hostility': 1,
#   'fund': 1,
#   'invest': 1,
#   'pollution': 1,
#   'Nipple-gate': 2,
#   'sickening': 1,
#   'supergroup': 2,
#   'bombarded': 1,
#   'great': 2,
#   'unscrupulous': 1,
#   'lewd': 1,
#   'offensive': 2,
#   'pre-masters': 2,
#   'jostled': 1,
#   'monumental': 2,
#   'cool': 3,
#   'exploits': 1,
#   'twisted': 1,
#   'threatening': 1,
#   'comfortable': 1,
#   'loopy': 1,
#   'stressed': 1,
#   'throne': 1,
#   'idiotic': 2,
#   'delight': 1,
#   'sizable': 1,
#   'challenge': 2,
#   'impressive': 1,
#   'bullying': 2,
#   'superior': 1,
#   'agendas': 1,
#   'hopeful': 1,
#   'recovering': 1,
#   'satisfied': 1,
#   'official': 1,
#   'haunted': 1,
#   'horrified': 1,
#   'devastated': 1,
#   'detested': 1,
#   'anti-gay': 1,
#   'classic': 1,
#   'Angels': 1,
#   'butcher': 1,
#   'black': 2,
#   'Jazz': 2,
#   'blues': 1,
#   'bebop': 1,
#   'ragtime': 1,
#   'Urban': 2,
#   'urban': 4,
#   'Fathead': 1,
#   'astounded': 1,
#   'dead': 1,
#   'dramatic': 1,
#   'disadvantaged': 1,
#   'rugby-tackled': 1,
#   'jackpot': 1,
#   'medium': 1,
#   'thrilled': 1,
#   'love': 1,
#   'horrible': 1,
#   'victim': 1,
#   'demeaning': 1,
#   'spark': 1,
#   'amazing': 1,
#   'ecstatic': 2,
#   'fiery': 1,
#   'snubbing': 1,
#   'false': 1,
#   'desperate': 1,
#   'Jimmy': 1,
#   'masterpiece': 1,
#   'retro': 1,
#   'exciting': 1,
#   'supersized': 1,
#   'shield': 1,
#   'desire': 1},
#  ('unwrapped', 'by'): {"''": 1},
#  ("''", 'sculptor'): {'by': 1},
#  ('by', 'Richard'): {'sculptor': 1},
#  ('sculptor', 'Wentworth'): {'Richard': 1},
#  ('Richard', ','): {'Wentworth': 1,
#   'Griffiths': 2,
#   'Gere': 2,
#   'Fogarty': 1,
#   'Diamond': 1,
#   'Dreyfuss': 1},
#  ('Wentworth', 'who'): {',': 1},
#  (',', 'is'): {'who': 17,
#   'Who': 1,
#   'and': 1,
#   'which': 37,
#   'there': 6,
#   'it': 7,
#   'he': 5,
#   'Davis': 1,
#   'Foxx': 1,
#   'this': 4,
#   'Gervais': 1,
#   'Angola': 1,
#   'that': 2,
#   'northing': 1,
#   'Bangkok': 1,
#   'nostalgia': 1,
#   'she': 1},
#  ('who', 'responsible'): {'is': 1},
#  ('is', 'for'): {'responsible': 3,
#   'up': 8,
#   'set': 1,
#   'nominated': 6,
#   'preparing': 1,
#   'known': 1,
#   'due': 3,
#   'looking': 1,
#   'waiting': 2,
#   'keen': 1,
#   'renowned': 1,
#   'calling': 1,
#   'booked': 1,
#   'not': 1,
#   'concern': 1,
#   'scheduled': 1},
#  ('responsible', 'decorating'): {'for': 1},
#  ('for', 'the'): {'decorating': 1,
#   'Not': 2,
#   'by': 7,
#   'sealing': 1,
#   'On': 1,
#   'breaking': 1,
#   'singing': 1,
#   '``': 1,
#   'all': 1,
#   'staging': 1,
#   'uncovering': 1,
#   'paving': 1},
#  ('decorating', 'tree'): {'the': 1},
#  ('the', 'with'): {'tree': 1,
#   'year': 1,
#   'fascination': 1,
#   'field': 2,
#   'top': 2,
#   'weekend': 3,
#   'surprises': 1,
#   'premiere': 1,
#   'favourite': 2,
#   'charts': 2,
#   'bars': 1,
#   'case': 1,
#   'UK': 2,
#   'show': 4,
#   'road': 2,
#   'awards': 1,
#   'chest': 1,
#   'programme': 1,
#   'stall': 1,
#   'way': 1,
#   'accuracy': 1,
#   'arrangements': 1,
#   'outsider': 1,
#   'chart': 1,
#   'water': 1,
#   'head': 2,
#   'ceremony': 1,
#   'group': 1,
#   'clash': 1,
#   'role': 1,
#   'star': 1,
#   'list': 1,
#   'world': 1,
#   'nominations': 1,
#   'script': 1},
#  ('tree', 'broken'): {'with': 1},
#  ('with', 'plates'): {'broken': 1},
#  ('broken', 'and'): {'plates': 1},
#  ('plates', 'light'): {'and': 1},
#  ('and', 'bulbs'): {'light': 1},
#  ('light', '.'): {'bulbs': 1},
#  ('bulbs', 'It'): {'.': 1},
#  ('.', 'is'): {'It': 32,
#   'Wentworth': 1,
#   'Bloom': 1,
#   'He': 14,
#   'One': 2,
#   'Miyagishima': 1,
#   'Sideways': 3,
#   'This': 8,
#   'There': 7,
#   'She': 7,
#   'Moreno': 2,
#   'Considine': 1,
#   'PBS': 1,
#   'Encore': 1,
#   'Barley': 1,
#   'Adoption': 1,
#   'Comeback': 1,
#   'Viacom': 1,
#   'That': 1,
#   'Clark': 2,
#   'Farrell': 1,
#   'Urban': 1,
#   'JK': 1,
#   'Filming': 2,
#   'Paver': 1,
#   'Corbett': 1,
#   'Hoffman': 1,
#   'Lee': 1,
#   'Tarantino': 1,
#   'Morrison': 1,
#   'Jackson': 1},
#  ('It', 'the'): {'is': 5,
#   'said': 1,
#   "'s": 5,
#   'credited': 1,
#   'tells': 1,
#   'features': 2,
#   'topped': 3,
#   'exploits': 1,
#   'says': 1,
#   'led': 1,
#   'was': 2,
#   'attributed': 1,
#   'will': 1,
#   'becomes': 1},
#  ('is', '17th'): {'the': 1},
#  ('the', 'year'): {'17th': 1,
#   'second': 1,
#   'first': 1,
#   'third': 1,
#   'previous': 2,
#   'following': 3,
#   'same': 3,
#   'past': 2,
#   'last': 2,
#   'financial': 1,
#   'coming': 1},
#  ('17th', 'that'): {'year': 1},
#  ('year', 'the'): {'that': 2,
#   'after': 1,
#   ',': 7,
#   'was': 3,
#   'by': 1,
#   'because': 1,
#   'in': 1,
#   'winning': 1,
#   'its': 1,
#   'with': 1},
#  ('that', 'gallery'): {'the': 2},
#  ('the', 'has'): {'gallery': 1,
#   'owner': 1,
#   'book': 3,
#   'hell': 1,
#   'star': 1,
#   'world': 1,
#   'film': 1,
#   'courthouse': 1,
#   'label': 1,
#   'government': 1,
#   'UK': 2,
#   'magazine': 1,
#   'family': 1,
#   'US': 1,
#   'comedian': 1,
#   'channel': 1,
#   'Academy': 1,
#   'BBC': 1,
#   'series': 1,
#   'singer': 1,
#   'album': 1,
#   'Pops': 1,
#   'radio': 1,
#   'song': 1,
#   'date': 1,
#   'show': 1,
#   'pig': 1,
#   'festival': 2,
#   'workforce': 1},
#  ('gallery', 'invited'): {'has': 1},
#  ('has', 'an'): {'invited': 1,
#   'become': 3,
#   'received': 1,
#   'drawn': 1,
#   'seen': 1,
#   'meant': 1,
#   'expressed': 1,
#   'won': 1,
#   'had': 1},
#  ('invited', 'artist'): {'an': 1},
#  ('an', 'to'): {'artist': 3,
#   'assistant': 1,
#   'opportunity': 1,
#   'effort': 4,
#   'attempt': 6,
#   'alternative': 3,
#   'edge': 1,
#   'embarassment': 1,
#   'idol': 1,
#   'end': 1,
#   'hour': 1},
#  ('artist', 'dress'): {'to': 1},
#  ('to', 'their'): {'dress': 1,
#   'share': 1,
#   'read': 1,
#   'trim': 2,
#   'pay': 2,
#   'self-censor': 1,
#   'choose': 1,
#   'return': 1,
#   'retain': 2,
#   'make': 1,
#   'pursue': 1,
#   'get': 1,
#   'score': 1,
#   'supply': 1,
#   'mark': 2,
#   'record': 4,
#   'turn': 1,
#   'continue': 1,
#   'protect': 2,
#   'call': 1,
#   'update': 1,
#   'find': 1,
#   'relocate': 1,
#   'host': 1,
#   'release': 1,
#   'have': 1,
#   'ask': 1,
#   'increase': 1,
#   'save': 1,
#   'judge': 1,
#   'secure': 1,
#   'meet': 1,
#   'challenge': 1},
#  ('dress', 'Christmas'): {'their': 1},
#  ('their', 'tree'): {'Christmas': 1},
#  ('Christmas', '.'): {'tree': 1, 'Day': 3, 'market': 1, 'specials': 1},
#  ('tree', 'Artists'): {'.': 1},
#  ('.', 'who'): {'Artists': 1,
#   'Customers': 1,
#   'Those': 2,
#   'Everyone': 1,
#   'Anybody': 1,
#   'Fans': 1,
#   'Anyone': 1,
#   'And': 2},
#  ('Artists', 'have'): {'who': 1},
#  ('who', 'decorated'): {'have': 1},
#  ('have', 'the'): {'decorated': 1,
#   'for': 1,
#   'banned': 1,
#   'made': 1,
#   'given': 1,
#   'won': 3,
#   'savaged': 1,
#   'demanded': 1,
#   'used': 1,
#   'said': 1,
#   'entered': 1,
#   'in': 1,
#   'met': 1,
#   'enabled': 2,
#   'thought': 1,
#   'screened': 1,
#   'urged': 1,
#   'underestimated': 1,
#   'seen': 1,
#   'heard': 1,
#   'joined': 1,
#   'broken': 1,
#   'included': 1,
#   'shared': 1,
#   'been': 1,
#   'hailed': 1,
#   'explored': 1,
#   'secured': 1},
#  ('decorated', 'Tate'): {'the': 1},
#  ('the', 'tree'): {'Tate': 1},
#  ('Tate', 'in'): {'tree': 1},
#  ('tree', 'previous'): {'in': 1},
#  ('in', 'years'): {'previous': 2,
#   'recent': 7,
#   'three': 2,
#   'six': 1,
#   '25': 4,
#   '20': 1,
#   'eight': 1,
#   'subsequent': 1,
#   'five': 2,
#   '23': 1,
#   'four': 1},
#  ('previous', 'include'): {'years': 1},
#  ('years', 'Tracey'): {'include': 1},
#  ('include', 'Emin'): {'Tracey': 1},
#  ('Tracey', 'in'): {'Emin': 1},
#  ('Emin', '2002'): {'in': 1},
#  ('in', '.'): {'2002': 11,
#   '2003': 14,
#   '1968': 3,
#   'Ballymena': 1,
#   'London': 5,
#   '1958': 2,
#   '2001': 8,
#   '1776': 1,
#   '1910': 1,
#   'America': 1,
#   'lifestyle': 1,
#   '1985': 3,
#   '1996': 4,
#   'Italy': 2,
#   '2004': 15,
#   '1989': 3,
#   'Dominica': 1,
#   'movies': 1,
#   '2006': 2,
#   'Closer': 6,
#   'February': 7,
#   '1949': 1,
#   'Belgium': 1,
#   'Kigali': 1,
#   'Paris': 1,
#   'January': 3,
#   'India': 3,
#   '1993': 4,
#   'Europe': 2,
#   'total': 3,
#   'two': 1,
#   'Ray': 2,
#   '1990': 1,
#   'film': 2,
#   'Hollywood': 1,
#   'Deadwood': 1,
#   'LA': 1,
#   'Iraq': 2,
#   'jail': 2,
#   'Utah': 1,
#   '1981': 3,
#   'Chechnya': 1,
#   'December': 4,
#   'Maryland': 1,
#   'Miami': 1,
#   '1979': 3,
#   '2000': 2,
#   'hospital': 2,
#   '1959': 1,
#   '1980': 1,
#   'Fulham': 1,
#   'music': 2,
#   'June': 3,
#   'April': 2,
#   'Switzerland': 1,
#   'Africa': 2,
#   'Florida': 3,
#   'Bakersfield': 1,
#   'September': 3,
#   'August': 2,
#   '1999': 3,
#   'November': 2,
#   '1984': 1,
#   'schools': 2,
#   'Rome': 3,
#   '1991': 2,
#   'tune': 1,
#   'it': 1,
#   'October': 5,
#   '1937': 2,
#   'production': 1,
#   '1962': 1,
#   'mid-air': 1,
#   'here': 1,
#   'Guernsey': 1,
#   'EastEnders': 1,
#   'society': 1,
#   'Wales': 2,
#   'general': 1,
#   '1978': 1,
#   'Wambo': 1,
#   'Fingersmith': 1,
#   '1957': 1,
#   'Birmingham': 2,
#   'March': 3,
#   'time': 1,
#   'China': 1,
#   '2005': 2,
#   '1998': 2,
#   '1987': 1,
#   'trouble': 1,
#   '1994': 2,
#   'common': 1,
#   '1965': 1,
#   '1982': 1,
#   'English': 1,
#   'July': 2,
#   '1997': 1,
#   'White': 1,
#   '1938': 1,
#   'there': 1,
#   'third': 2,
#   'England': 1,
#   'Canada': 1,
#   '1948': 1,
#   'May': 1,
#   '1952': 1,
#   'Glasgow': 1,
#   '1934': 1,
#   '1939': 1,
#   'Chocolat': 1,
#   'history': 2,
#   'condoms': 1,
#   'television': 1,
#   'rest': 1,
#   'Brussels': 1,
#   'public': 1,
#   'Alias': 1,
#   '2007': 1,
#   'prison': 1,
#   'France': 1,
#   '1969': 1,
#   'Germany': 1,
#   'Wellington': 1},
#  ('The', 'green'): {'plain': 1},
#  ('plain', 'Norway'): {'green': 1},
#  ('green', 'spruce'): {'Norway': 1},
#  ('Norway', 'is'): {'spruce': 1},
#  ('spruce', 'displayed'): {'is': 1},
#  ('is', 'in'): {'displayed': 1,
#   'set': 5,
#   'now': 2,
#   'auctioned': 1,
#   'also': 1,
#   'trapped': 1,
#   'seen': 2,
#   'God-like': 1,
#   'holidaying': 1,
#   'due': 1,
#   'already': 1,
#   'released': 2,
#   'starring': 1,
#   '91st': 1,
#   'pencilled': 1,
#   'reflected': 1,
#   'made': 1,
#   'anyone': 1,
#   '``': 1,
#   'currently': 2,
#   'working': 1,
#   'held': 1,
#   'nominated': 1,
#   'out': 1,
#   'put': 1},
#  ('displayed', 'the'): {'in': 1},
#  ('in', 'gallery'): {'the': 1},
#  ('the', "'s"): {'gallery': 2,
#   'children': 7,
#   'nanny': 1,
#   'musical': 2,
#   'Cuckoo': 2,
#   'RSC': 1,
#   'council': 2,
#   'work': 1,
#   'play': 2,
#   'BBC': 11,
#   'RCA': 1,
#   'UK': 12,
#   'prize': 1,
#   '1980': 1,
#   'artist': 1,
#   'company': 4,
#   'book': 1,
#   'country': 7,
#   'film': 13,
#   'group': 3,
#   'festival': 7,
#   'Hollywood': 4,
#   'movie': 1,
#   'DVD': 2,
#   'nation': 2,
#   'producer': 1,
#   'show': 12,
#   'People': 2,
#   'industry': 1,
#   'band': 15,
#   'year': 3,
#   'star': 1,
#   'week': 1,
#   'woman': 2,
#   'weather': 1,
#   'song': 1,
#   'killer': 1,
#   'singer': 5,
#   'University': 1,
#   'night': 4,
#   'event': 2,
#   'city': 2,
#   'station': 3,
#   'magazine': 2,
#   'channel': 2,
#   'contest': 1,
#   'network': 2,
#   'FCC': 2,
#   'people': 2,
#   'capital': 1,
#   'committee': 1,
#   'programme': 4,
#   'album': 2,
#   'school': 1,
#   'actor': 1,
#   'DJ': 1,
#   'venue': 1,
#   'record': 1,
#   'tour': 1,
#   'scene': 1,
#   'musician': 1,
#   'radio': 1,
#   'NME': 1,
#   'guitarist': 1,
#   'Billboard': 1,
#   'director': 2,
#   'rapper': 1,
#   '24-year-old': 1,
#   'world': 2,
#   'judge': 1,
#   'story': 1,
#   'original': 2,
#   'public': 1,
#   'Observer': 1,
#   'Academy': 1,
#   'accuser': 1,
#   'boy': 1,
#   'prosecution': 2,
#   'Director': 1},
#  ('gallery', 'foyer'): {"'s": 1},
#  ("'s", '.'): {'foyer': 1,
#   'winner': 1,
#   'Nest': 1,
#   'empowerment': 1,
#   'demise': 1,
#   'limelight': 1,
#   'Shoes': 1,
#   'chief': 1,
#   'ceremony': 1,
#   'credit': 2,
#   'funeral': 2,
#   'murder': 1,
#   '12': 1,
#   'Oscars': 5,
#   'Cesars': 1,
#   'mother': 1,
#   'colder': 1,
#   'spell': 1,
#   'regime': 1,
#   'office': 1,
#   'Graceland': 1,
#   'career': 1,
#   'birth': 3,
#   'place': 2,
#   'site': 1,
#   'recording': 1,
#   'Closer': 1,
#   'show': 1,
#   'part': 1,
#   'anniversary': 1,
#   'cave': 1,
#   'Kitchen': 1,
#   'perceptions': 1,
#   'slot': 1,
#   'action': 1,
#   'history': 1,
#   'conference': 1,
#   'Schooldays': 1,
#   'producers': 2,
#   'family': 1,
#   'death': 1,
#   'box': 2,
#   'Christmas': 1,
#   'departure': 1,
#   '1,000th': 1,
#   'artwork': 1,
#   'event': 1,
#   "'orrible": 1,
#   'regressive': 1,
#   'headquarters': 1,
#   'reception': 1,
#   'wrong': 1,
#   'home': 2,
#   'songs': 1,
#   'earpiece': 1,
#   'entourage': 1,
#   'release': 1,
#   'Requiem': 1,
#   'script': 1,
#   'teacher': 1,
#   'characters': 1,
#   'festival': 1,
#   'Web': 1,
#   'novel': 1,
#   'book': 1,
#   'skyscrapers': 1,
#   'covers': 1,
#   'catastrophe': 1,
#   'vehicle': 1,
#   'life': 1,
#   'work': 1,
#   'backfiring': 1,
#   'music': 1,
#   'programme': 1,
#   'programs': 1,
#   'car': 1,
#   'Inc': 1,
#   'film': 2,
#   'imagination': 1,
#   'mouth': 1,
#   'incredible': 1},
#  ('foyer', 'Its'): {'.': 1},
#  ('.', 'light'): {'Its': 1},
#  ('Its', 'bulb'): {'light': 1},
#  ('light', 'adornments'): {'bulb': 1},
#  ('bulb', 'are'): {'adornments': 1},
#  ('adornments', 'dimmed'): {'are': 1},
#  ('are', ','): {'dimmed': 1,
#   'British': 1,
#   'confirmed': 1,
#   'interrupted': 1,
#   'commentaries': 1,
#   'formulaic': 1,
#   'catchy': 1,
#   'kidding': 1,
#   'judged': 1,
#   'down': 1,
#   'booming': 1},
#  ('dimmed', 'ordinary'): {',': 1},
#  (',', 'domestic'): {'ordinary': 1},
#  ('ordinary', 'ones'): {'domestic': 1},
#  ('domestic', 'joined'): {'ones': 1},
#  ('ones', 'together'): {'joined': 1},
#  ('joined', 'with'): {'together': 1, 'forces': 1},
#  ('together', 'string'): {'with': 1},
#  ('with', '.'): {'string': 1,
#   'fundraising': 1,
#   '2003': 1,
#   'Grudge': 1,
#   'her': 2,
#   'Howard': 1,
#   'Day-Lewis': 2,
#   'marijuana': 1,
#   'them': 1,
#   'him': 1,
#   'Breathe': 1,
#   'Filthy/Gorgeous': 1,
#   'depression': 1,
#   'me': 2,
#   'us': 1,
#   'age': 1,
#   '£5m': 1,
#   'praise': 1,
#   'beads': 1,
#   'Buhecha': 1,
#   'casualty': 1,
#   '11': 1,
#   'Carpenter': 1},
#  ('string', 'The'): {'.': 1},
#  ('.', 'plates'): {'The': 1},
#  ('The', 'decorating'): {'plates': 1},
#  ('plates', 'the'): {'decorating': 1},
#  ('decorating', 'branches'): {'the': 1},
#  ('the', 'will'): {'branches': 1,
#   'sale': 2,
#   'collection': 1,
#   'contest': 1,
#   'episode': 1,
#   'FCC': 1,
#   'awards': 1,
#   'ceremony': 1,
#   'song': 1,
#   'show': 1,
#   'album': 1,
#   'audience': 1,
#   'Pops': 2,
#   '28-year-old': 1,
#   'film': 1,
#   'fans': 1,
#   'band': 1,
#   'musical': 1,
#   'unexpected': 1,
#   'winners': 1,
#   'Park': 1,
#   'concert': 1,
#   'cast': 1,
#   'stunts': 1,
#   'years': 1,
#   'museum': 2},
#  ('branches', 'be'): {'will': 1},
#  ('will', 'auctioned'): {'be': 2},
#  ('be', 'off'): {'auctioned': 1, 'voted': 2, 'sold': 1},
#  ('auctioned', 'for'): {'off': 1},
#  ('off', 'the'): {'for': 1, 'of': 1},
#  ('for', 'children'): {'the': 1, 'young': 1},
#  ('children', 'charity'): {"'s": 1},
#  ("'s", 'ArtWorks'): {'charity': 1},
#  ('charity', '.'): {'ArtWorks': 1,
#   'element': 1,
#   'prize': 2,
#   'appeal': 1,
#   'song': 1},
#  ('ArtWorks', 'Wentworth'): {'.': 1},
#  ('.', 'worked'): {'Wentworth': 1, 'Hailey': 1, 'He': 1},
#  ('Wentworth', 'as'): {'worked': 1},
#  ('worked', 'an'): {'as': 1},
#  ('as', 'assistant'): {'an': 1},
#  ('assistant', 'sculptor'): {'to': 1},
#  ('to', 'Henry'): {'sculptor': 1},
#  ('sculptor', 'Moore'): {'Henry': 1},
#  ('Henry', 'in'): {'Moore': 1, 'Fonda': 1},
#  ('Moore', 'the'): {'in': 1, 'told': 1},
#  ('in', 'late'): {'the': 3, 'his': 1},
#  ('the', '1960s'): {'late': 2, 'original': 1},
#  ('late', '.'): {'1960s': 1, 'father': 1, '2007': 1},
#  ('1960s', 'His'): {'.': 1},
#  ('.', 'reputation'): {'His': 1},
#  ('His', 'as'): {'reputation': 1},
#  ('reputation', 'a'): {'as': 2},
#  ('as', 'sculptor'): {'a': 1},
#  ('a', 'grew'): {'sculptor': 1},
#  ('sculptor', 'in'): {'grew': 1},
#  ('grew', 'the'): {'in': 1},
#  ('in', '1980s'): {'the': 9},
#  ('the', ','): {'1980s': 10,
#   'stage': 4,
#   'genre': 1,
#   'book': 5,
#   'capital': 2,
#   'world': 8,
#   'hypocrisy': 1,
#   'theatre': 2,
#   'mid-70s': 1,
#   'form': 1,
#   'sky': 1,
#   'Bahamas': 1,
#   'show': 9,
#   'country': 4,
#   'RAD': 1,
#   'piano': 2,
#   'UK': 7,
#   'US': 28,
#   'better': 1,
#   'screenplay': 1,
#   'invasion': 1,
#   'figures': 1,
#   'merrier': 1,
#   'warm': 1,
#   'year': 11,
#   'Dead': 2,
#   'square': 1,
#   'star': 1,
#   'story': 3,
#   'film': 16,
#   'idea': 2,
#   'streets': 1,
#   'running': 1,
#   'festival': 4,
#   'World': 3,
#   'lawsuit': 2,
#   'murders': 1,
#   'Phoenix': 2,
#   'part': 4,
#   'fleshiness': 1,
#   'shortlist': 1,
#   'event': 1,
#   'stops': 1,
#   'market': 1,
#   'ceremony': 6,
#   'novel': 2,
#   'poll': 1,
#   'Sea': 2,
#   'Knife': 1,
#   '1950s': 1,
#   'results': 1,
#   'Kranks': 1,
#   'weekend': 3,
#   'winners': 1,
#   '1940s': 1,
#   'films': 1,
#   'Church': 1,
#   'Authority': 1,
#   'individual': 1,
#   'piece': 1,
#   'Oscars': 2,
#   'elite': 1,
#   'follow-up': 2,
#   'trial': 2,
#   'years': 1,
#   'recording': 1,
#   'studio': 3,
#   'past': 3,
#   'obvious': 1,
#   'greatest': 1,
#   'project': 2,
#   'album': 1,
#   'carnival': 1,
#   'Maracana': 1,
#   'road': 2,
#   'video': 1,
#   'Byrds': 3,
#   'mid-1960s': 1,
#   'rumours': 1,
#   'public': 2,
#   'list': 4,
#   'Brits': 1,
#   'earth': 1,
#   'band': 7,
#   'anger': 1,
#   'title': 1,
#   '8,000': 1,
#   'system': 1,
#   'venue': 1,
#   'police': 1,
#   'house': 3,
#   'survey': 2,
#   'Atlantic': 3,
#   'single': 3,
#   'sample': 1,
#   'scheme': 1,
#   'killing': 1,
#   'Beatles': 1,
#   'awards': 2,
#   'money': 1,
#   'music': 2,
#   'fight': 2,
#   'time': 4,
#   'order': 1,
#   'auction': 1,
#   'line-up': 1,
#   'body': 1,
#   'series': 2,
#   'Beautiful': 1,
#   'air': 1,
#   'sale': 2,
#   'pieces': 1,
#   'walls': 1,
#   'lock-up': 1,
#   'advert': 1,
#   'programme': 3,
#   'contest': 1,
#   'mid-1990s': 1,
#   'globe': 1,
#   'dancefloor': 1,
#   'BBC': 1,
#   'programmes': 1,
#   'roof': 1,
#   'case': 3,
#   'courtroom': 1,
#   'resources': 1,
#   'same': 2,
#   'marvellous': 1,
#   'playground': 1,
#   'claim': 1,
#   'audience': 4,
#   'missing': 1,
#   'villages': 1,
#   'bush': 1,
#   'industry': 3,
#   'cleaners': 1,
#   'final': 1,
#   'Navy': 1,
#   'plane': 1,
#   'mid-week': 1,
#   'score': 1,
#   'day': 1,
#   'tour': 1,
#   'song': 1,
#   'upside': 1,
#   'scene': 1,
#   'Park': 1,
#   'Streets': 1,
#   'labels': 1,
#   'building': 1,
#   'second': 1,
#   'Wire': 1,
#   'top': 1,
#   'radio': 1,
#   'start': 1,
#   'four': 1,
#   'Gielgud': 1,
#   'Libertines': 1,
#   'front': 1,
#   'curfew': 1,
#   'Volksoper': 1,
#   'name': 1,
#   'sun': 1,
#   'scenes': 1,
#   'orchestra': 1,
#   'technology': 1,
#   'charts': 1,
#   'Pretenders': 2,
#   "O'Jays": 1,
#   'singer': 1,
#   'gig': 1,
#   'cast': 3,
#   'musical': 1,
#   'production': 1,
#   'Whale': 1,
#   'pig': 1,
#   'sidekick': 1,
#   'internet': 1,
#   'West': 1,
#   'chart': 3,
#   'House': 1,
#   'war': 1,
#   'Academy': 2,
#   'Fockers': 4,
#   'movies': 1,
#   'Caribbean': 1,
#   'new': 1,
#   'Friday': 1,
#   'Rings': 2,
#   'train': 1,
#   'camera': 1,
#   'Baftas': 2,
#   'cards': 1,
#   'Wheelies': 1,
#   'Builder': 1,
#   'city': 2,
#   'Christ': 2,
#   'movie': 1,
#   'Mask': 1,
#   'bag': 1,
#   'category': 1,
#   'breadline': 2,
#   'fuss': 1,
#   'future': 1,
#   'night': 1,
#   'broadcast': 1,
#   'prosecution': 1,
#   'ranks': 1,
#   '1960s': 1,
#   'devil': 1},
#  ('1980s', 'while'): {',': 1},
#  (',', 'he'): {'while': 1,
#   "''": 142,
#   'where': 9,
#   'when': 3,
#   'said': 8,
#   'and': 8,
#   'which': 7,
#   'claiming': 3,
#   'though': 3,
#   'because': 3,
#   'but': 2,
#   'saying': 1,
#   'alleging': 1,
#   'who': 1,
#   'suggested': 1,
#   'as': 1,
#   'whom': 1},
#  ('while', 'has'): {'he': 1, 'Sideways': 1, 'Osbourne': 1, 'it': 1},
#  ('he', 'been'): {'has': 4, "'s": 2, 'had': 4},
#  ('has', 'one'): {'been': 3,
#   'become': 2,
#   'released': 1,
#   'lost': 1,
#   'scooped': 1},
#  ('been', 'of'): {'one': 4, 'kind': 1, 'accused': 1, 'out': 1, 'deprived': 1},
#  ('one', 'the'): {'of': 68, ',': 1, 'in': 12, 'for': 1, 'is': 1},
#  ('of', 'most'): {'the': 22, 'his': 2, 'its': 1},
#  ('the', 'influential'): {'most': 4},
#  ('most', 'teachers'): {'influential': 1},
#  ('influential', 'during'): {'teachers': 1},
#  ('teachers', 'the'): {'during': 1},
#  ('during', 'last'): {'the': 1},
#  ('the', 'two'): {'last': 4,
#   'top': 1,
#   'band': 1,
#   'final': 1,
#   'first': 1,
#   'number': 2,
#   'past': 1},
#  ('last', 'decades'): {'two': 1},
#  ('two', '.'): {'decades': 1,
#   'years': 5,
#   'days': 1,
#   'musicians': 1,
#   'shootings': 1},
#  ('decades', 'Wentworth'): {'.': 1},
#  ('Wentworth', 'also'): {'is': 1},
#  ('is', 'known'): {'also': 1, 'barely': 1, 'affectionately': 1, 'best': 1},
#  ('also', 'for'): {'known': 1,
#   'nominated': 4,
#   'responsible': 2,
#   'up': 6,
#   'hard': 1,
#   'dominated': 1,
#   'available': 1,
#   'called': 1,
#   'adapted': 1},
#  ('known', 'his'): {'for': 7},
#  ('for', 'photography'): {'his': 1},
#  ('his', 'of'): {'photography': 1,
#   'production': 2,
#   'wife': 2,
#   'portrayal': 2,
#   'odds': 2,
#   'chances': 2,
#   'opinion': 1,
#   'interpretations': 1},
#  ('photography', 'mundane'): {'of': 1},
#  ('of', ','): {'mundane': 1,
#   'us': 3,
#   'Scots': 1,
#   'scholarship': 2,
#   'Durham': 1,
#   'Jesus': 1,
#   'publications': 1,
#   'all': 1,
#   '84': 1,
#   'years': 4,
#   'films': 1,
#   'Giselle': 1,
#   'books': 2,
#   'Justice': 1,
#   'Caravaggio': 1,
#   'Azkaban': 5,
#   'Underexposure': 1,
#   'roles': 1,
#   'Dominica': 1,
#   'Grace': 2,
#   'discovery': 1,
#   'excellence': 1,
#   '80': 2,
#   'regulation': 1,
#   'film': 1,
#   '06/05': 1,
#   'I': 1,
#   'money': 1,
#   'Paris': 1,
#   'forgotten': 1,
#   'Love': 2,
#   'good': 2,
#   'Fame': 4,
#   'here': 1,
#   'God': 1,
#   'Iraq': 1,
#   'ours': 1,
#   'destruction': 1,
#   'Thunderbirds': 2,
#   'Radiohead': 1,
#   'Fire': 1,
#   'them': 2,
#   'Korn': 1,
#   'rock': 1,
#   'purchasers': 1,
#   'view': 2,
#   'tickets': 1,
#   'jewellery': 1,
#   '2004': 2,
#   'adoption': 1,
#   'irresponsibility': 1,
#   'Representatives': 1,
#   'entertainment': 1,
#   '93': 1,
#   'growth': 2,
#   'Music': 1,
#   'this': 1,
#   'Frost': 1,
#   'execution': 1,
#   'parliament': 1,
#   '40-1': 1,
#   'T-shirts': 1,
#   'war': 1,
#   'broadcasting': 1,
#   'France': 1,
#   'Wambo': 1,
#   'Ian': 1,
#   'it': 3,
#   'Smog': 1,
#   'students': 1,
#   'Goa': 1,
#   'Spears': 1,
#   'thing': 2,
#   'crap': 1,
#   'hardcore': 1,
#   'sub-genres': 1,
#   'really': 1,
#   'hip-hop': 1,
#   'soul': 1,
#   '2002': 1,
#   'Souls': 1,
#   'instruments': 1,
#   'Austria': 1,
#   'music': 1,
#   'success': 1,
#   'text': 1,
#   'dollars': 1,
#   'film-making': 1,
#   'Lock': 1,
#   '1857': 1,
#   'Reason': 1,
#   'factors': 1,
#   'Torak': 1,
#   'Batman': 1,
#   'comics': 1,
#   'titles': 1,
#   'Graceland': 1,
#   '79': 1,
#   'Victoria': 1,
#   'Reading': 1,
#   'safer': 1,
#   'cinematography': 1,
#   'comedy': 1,
#   'time': 2,
#   '6-9': 1,
#   'palaeontologists': 1,
#   'Abba': 1,
#   'Zorro': 2,
#   'Darkness': 1,
#   'mouth': 1,
#   'awards': 1,
#   'fire': 1,
#   'big-screen': 1,
#   'Winn-Dixie': 1,
#   'CSI': 2,
#   'Shameless': 1},
#  ('mundane', 'everyday'): {',': 1},
#  (',', 'subjects'): {'everyday': 1},
#  ('everyday', 'such'): {'subjects': 1},
#  ('subjects', 'as'): {'such': 1},
#  ('such', 'a'): {'as': 4},
#  ('as', 'cigarette'): {'a': 1},
#  ('a', 'packet'): {'cigarette': 1},
#  ('cigarette', 'jammed'): {'packet': 1},
#  ('packet', 'under'): {'jammed': 1},
#  ('jammed', 'the'): {'under': 1},
#  ('under', 'wonky'): {'the': 1},
#  ('the', 'leg'): {'wonky': 1},
#  ('wonky', 'of'): {'leg': 1},
#  ('leg', 'a'): {'of': 1},
#  ('of', 'table'): {'a': 1},
#  ('a', '.'): {'table': 1,
#   'bestseller': 1,
#   'citizen': 1,
#   'bomb': 1,
#   'collector': 1,
#   'teacher': 1,
#   'synopsis': 1,
#   'year': 2,
#   'canal': 1,
#   'Democrat': 1,
#   'statement': 4,
#   'film': 4,
#   'movie': 1,
#   'stepchild': 1,
#   'fire': 1,
#   'minx': 1,
#   'backer': 1,
#   'witch': 1,
#   'disappointment': 1,
#   'row': 2,
#   'vacation': 1,
#   'rehearsal': 1,
#   'halt': 2,
#   'neighbour': 1,
#   'musician': 1,
#   'hurry': 1,
#   'fine': 3,
#   'conviction': 1,
#   'nightclub': 1,
#   'female': 1,
#   'restaurant': 1,
#   'day': 2,
#   'limousine': 1,
#   'headache': 1,
#   'church': 1,
#   'comedy': 1,
#   'problem': 2,
#   'musical': 1,
#   'doorway': 1,
#   'night': 1,
#   'couple': 1,
#   'while': 1,
#   'travesty': 1,
#   'song': 1,
#   'century': 1,
#   'joke': 1,
#   'chance': 1,
#   'time': 1,
#   'pub': 1,
#   'commodity': 2,
#   'mess': 1,
#   'producer': 1,
#   'blessing': 1,
#   'catsuit': 1,
#   'cliche': 1,
#   'duet': 1,
#   'classic': 2,
#   'zombie': 1,
#   'month': 1,
#   'change': 1,
#   'refund': 1,
#   'visa': 1,
#   'hiatus': 1,
#   'relative': 1,
#   'tiger': 1,
#   'page': 1,
#   'baby': 1,
#   'comeback': 2,
#   'dinner': 1,
#   'week': 1,
#   'star': 1,
#   'decline': 1,
#   'lake': 1,
#   'souvenir': 1,
#   'lawyer': 1,
#   'child': 2,
#   'shame': 1,
#   'certainty': 1,
#   'date': 1,
#   'dream': 1,
#   'psychopath': 1,
#   'tragedy': 1},
#  ('Jarre', 'fairytale'): {'joins': 1},
#  ('joins', 'celebration'): {'fairytale': 1},
#  ('French', 'Jean-Michel'): {'musician': 1},
#  ('musician', 'Jarre'): {'Jean-Michel': 1},
#  ('Jean-Michel', 'is'): {'Jarre': 1},
#  ('Jarre', 'to'): {'is': 1},
#  ('is', 'perform'): {'to': 2},
#  ('to', 'at'): {'perform': 6,
#   'look': 3,
#   'show': 2,
#   'raise': 1,
#   'play': 1,
#   'sell': 2,
#   'speak': 1,
#   'triumph': 1,
#   'appear': 1,
#   'me': 1,
#   'be': 1},
#  ('perform', 'a'): {'at': 1},
#  ('at', 'concert'): {'a': 3, 'the': 1},
#  ('a', 'in'): {'concert': 4,
#   'boost': 1,
#   'movie': 1,
#   'film': 2,
#   'governess': 1,
#   'funeral': 2,
#   'ceremony': 2,
#   'protest': 1,
#   'priest': 2,
#   'regular': 1,
#   'challenge': 1,
#   'week': 3,
#   'party': 1,
#   'producer': 1,
#   'year': 1,
#   'minimum': 2,
#   'church': 1,
#   'table': 1,
#   'break-in': 1,
#   'Grammy': 1,
#   'sample': 1,
#   'decline': 1,
#   'career': 1,
#   'debate': 1,
#   'back-up': 2,
#   'fight': 1,
#   'decade': 2,
#   'failure': 1,
#   'child': 1,
#   'close': 2,
#   'flop': 1,
#   'stall': 1,
#   'rally': 1,
#   'message': 1,
#   'square': 1,
#   'conman': 1,
#   'drop': 2,
#   'show': 1,
#   'hat-trick': 1,
#   'kick': 1,
#   'Bottle': 1,
#   'flower': 1,
#   'gravestone': 1,
#   'guy': 1,
#   'suspect': 1,
#   '16-year-old': 1,
#   'moment': 1,
#   'teenager': 1,
#   'step': 1,
#   'spider': 1,
#   'rat': 1,
#   'fall': 1,
#   'job': 1,
#   'soldier': 1,
#   'degree': 1,
#   'cameo': 1,
#   'nomination': 1,
#   'pianist': 1,
#   'Bafta': 1,
#   'car': 1,
#   'lock-up': 1,
#   'realisation': 1,
#   'picture': 1},
#  ('concert', 'Copenhagen'): {'in': 1},
#  ('in', 'to'): {'Copenhagen': 1,
#   'bid': 1,
#   'response': 3,
#   'reference': 2,
#   'costumes': 1,
#   'Paris': 1,
#   'music': 1,
#   'order': 5,
#   'specifically': 2,
#   'Bakersfield': 1,
#   'London': 2,
#   'relation': 5,
#   'discussions': 1,
#   'just': 1,
#   '1995': 1,
#   'time': 1,
#   'place': 1,
#   'contrast': 1,
#   'Rutland': 1,
#   'stature': 1,
#   'regard': 1,
#   'addition': 1,
#   'Newcastle': 1,
#   '2003': 1,
#   '1922': 1,
#   'Sydney': 1,
#   'tribute': 1,
#   'talks': 1,
#   'history': 1},
#  ('Copenhagen', 'mark'): {'to': 1},
#  ('to', 'the'): {'mark': 5,
#   'join': 3,
#   'buy': 8,
#   'use': 3,
#   'win': 19,
#   'read': 1,
#   'decide': 2,
#   'attract': 1,
#   'make': 9,
#   'all': 1,
#   'reverse': 1,
#   're-ignite': 1,
#   'complete': 1,
#   'be': 16,
#   'enter': 1,
#   'direct': 6,
#   'document': 1,
#   'maintain': 1,
#   'celebrate': 5,
#   'walk': 1,
#   'land': 2,
#   'limit': 2,
#   'tighten': 1,
#   'restore': 1,
#   'guarantee': 1,
#   'become': 5,
#   'match': 3,
#   'find': 7,
#   'hear': 2,
#   'save': 4,
#   'reveal': 1,
#   'refuse': 1,
#   'play': 9,
#   'silence': 1,
#   'fill': 3,
#   'cover': 1,
#   'pass': 1,
#   'see': 8,
#   'buck': 1,
#   'wipe': 1,
#   'allow': 1,
#   'grace': 1,
#   'back': 1,
#   'end': 2,
#   'conquer': 1,
#   'take': 8,
#   'run': 1,
#   'withdraw': 1,
#   'cancel': 2,
#   'clear': 1,
#   'keep': 3,
#   'overthrow': 1,
#   'change': 1,
#   'introduce': 2,
#   'solve': 1,
#   'Meet': 2,
#   'receive': 2,
#   'quit': 3,
#   'consider': 1,
#   'remain': 1,
#   'top': 2,
#   'pull': 1,
#   'censor': 1,
#   'spend': 1,
#   'leave': 5,
#   'resume': 1,
#   'defeat': 1,
#   'rediscover': 1,
#   'have': 3,
#   'reinforce': 1,
#   'provide': 1,
#   'line': 1,
#   'create': 1,
#   'crack': 1,
#   'carry': 1,
#   'access': 2,
#   'license': 1,
#   'represent': 1,
#   'launch': 2,
#   'file': 1,
#   'let': 2,
#   'divulge': 1,
#   'raise': 1,
#   'ignore': 2,
#   'release': 1,
#   'pre-empt': 1,
#   'pick': 1,
#   'rocking': 1,
#   'perform': 1,
#   'co-present': 1,
#   'revitalise': 1,
#   'host': 2,
#   'confirm': 1,
#   'watch': 1,
#   'me': 1,
#   'benefit': 1,
#   'collect': 1,
#   'showcasing': 2,
#   'continue': 1,
#   'pay': 2,
#   'scrutiny': 1,
#   'rewrite': 1,
#   'support': 1,
#   'sue': 2,
#   'sell': 1,
#   'uncover': 1,
#   'lead': 1,
#   'split': 1,
#   'place': 1,
#   'close': 1,
#   'get': 2,
#   'do': 2,
#   'appear': 1,
#   'examine': 1,
#   'beat': 1,
#   'design': 1,
#   'regulate': 1,
#   'give': 2,
#   'sidestep': 1,
#   'describe': 1,
#   'undermine': 1,
#   'turn': 1,
#   'demolish': 1,
#   'move': 1,
#   'pave': 1,
#   'imagine': 1,
#   'thank': 2,
#   'observe': 1,
#   'embrace': 1,
#   'entertain': 1,
#   'headline': 2,
#   'attend': 1,
#   're-schedule': 1,
#   'protect': 2,
#   'premiere': 1,
#   'hit': 2,
#   'accommodate': 1,
#   'rid': 1,
#   'sate': 1,
#   'attain': 1,
#   'bemoan': 1,
#   'how': 1,
#   'criticise': 1,
#   'go': 2,
#   'bring': 1,
#   'commemorate': 1,
#   'explore': 1,
#   'mention': 1,
#   'discover': 1,
#   'discuss': 1,
#   'adapt': 1},
#  ('mark', 'bicentennial'): {'the': 1},
#  ('the', 'of'): {'bicentennial': 1,
#   'birth': 3,
#   'life': 6,
#   'producer': 2,
#   'idea': 4,
#   'success': 14,
#   'heads': 1,
#   'University': 9,
#   'End': 2,
#   'origins': 1,
#   'world': 4,
#   'organisers': 1,
#   'guise': 1,
#   'notions': 1,
#   'apparatus': 1,
#   'opening': 1,
#   'start': 5,
#   'founder': 2,
#   'careers': 2,
#   'Glens': 1,
#   'influence': 2,
#   'winner': 3,
#   'evolution': 1,
#   'science': 1,
#   'turn': 2,
#   'scope': 1,
#   'age': 28,
#   'popularity': 1,
#   'height': 3,
#   'attention': 2,
#   'highlights': 1,
#   'role': 9,
#   'direction': 1,
#   'illusion': 1,
#   'number': 12,
#   'children': 3,
#   'thrill': 1,
#   'rebirth': 2,
#   'quality': 2,
#   'events': 1,
#   'day': 2,
#   'story': 21,
#   'pedestrianisation': 1,
#   'Age': 1,
#   'work': 3,
#   'Association': 1,
#   'rest': 9,
#   'help': 2,
#   'brother': 1,
#   'Prisoner': 8,
#   'most': 2,
#   'author': 2,
#   'form': 2,
#   'writing': 1,
#   'screening': 2,
#   'toppling': 1,
#   'lives': 2,
#   'treatment': 2,
#   'importance': 3,
#   'attitude': 1,
#   'profile': 1,
#   'progression': 1,
#   'making': 1,
#   'films': 1,
#   'co-chairmen': 1,
#   'deadline': 1,
#   'arrival': 2,
#   'spirit': 2,
#   'centre': 3,
#   'island': 1,
#   'cause': 2,
#   'glamour': 1,
#   'list': 4,
#   'Academy': 5,
#   'members': 3,
#   'integrity': 2,
#   'daughter': 2,
#   'funerals': 1,
#   'title': 6,
#   'Centre': 2,
#   'proportion': 2,
#   'King': 1,
#   'death': 5,
#   'art': 2,
#   'annals': 1,
#   'light': 1,
#   'threat': 3,
#   'top': 14,
#   'filming': 1,
#   'firing': 1,
#   'appearance': 1,
#   'novel': 1,
#   'sight': 1,
#   'plight': 1,
#   'set': 1,
#   'murder': 2,
#   'wake': 1,
#   'eyes': 2,
#   'involvement': 1,
#   'classics': 1,
#   'sort': 1,
#   'side': 1,
#   'course': 2,
#   'vicissitudes': 1,
#   'contents': 1,
#   'lack': 1,
#   'travails': 1,
#   'pleasures': 1,
#   'beginning': 2,
#   'choice': 2,
#   'Fourth': 1,
#   'Lord': 4,
#   'diversity': 1,
#   'tale': 2,
#   'fate': 1,
#   'presenter': 2,
#   'production': 2,
#   'front': 1,
#   'City': 2,
#   'withdrawal': 1,
#   'portrayal': 1,
#   'vice-president': 1,
#   'director': 2,
#   'film': 1,
#   'majority': 4,
#   'CEO': 1,
#   'member': 1,
#   'legacy': 1,
#   'archive': 1,
#   'summer': 1,
#   'launch': 1,
#   'possibility': 1,
#   'freedom': 1,
#   'villains': 1,
#   'climate': 1,
#   'performance': 1,
#   'theme': 1,
#   'end': 21,
#   'victims': 2,
#   'verge': 2,
#   'helm': 2,
#   'footsteps': 2,
#   'responses': 1,
#   'city': 3,
#   'terms': 1,
#   'remix': 1,
#   'history': 4,
#   'Herald-Mail': 1,
#   'risk': 1,
#   'whole': 1,
#   'power': 2,
#   'closure': 1,
#   'folding': 1,
#   'demise': 1,
#   'deaths': 2,
#   'news': 3,
#   'smell': 1,
#   'value': 1,
#   'means': 1,
#   'extent': 1,
#   'pockets': 1,
#   'exponents': 1,
#   'last': 1,
#   'names': 1,
#   'streets': 1,
#   'birthday': 1,
#   'survey': 2,
#   'subject': 2,
#   'Sound': 3,
#   'summit': 1,
#   'mould': 2,
#   'line-up': 2,
#   'use': 2,
#   'issues': 1,
#   'interests': 1,
#   'Value': 1,
#   'creatives': 1,
#   'mother': 1,
#   'statute': 1,
#   'presence': 1,
#   'family': 1,
#   'album': 1,
#   'table': 1,
#   'widow': 2,
#   'likes': 4,
#   'sales': 1,
#   'cost': 1,
#   'forefront': 1,
#   'goings-on': 1,
#   'House': 1,
#   'nature': 1,
#   'producers': 1,
#   'president': 1,
#   'rankings': 1,
#   'ostentation': 1,
#   'back': 1,
#   'shadow': 1,
#   'crew': 1,
#   'format': 1,
#   'victim': 1,
#   'heels': 1,
#   'Emperor': 1,
#   'case': 2,
#   'perception': 1,
#   'near-infallibility': 1,
#   'Advancement': 1,
#   'families': 1,
#   'banner': 1,
#   'hosts': 2,
#   'range': 2,
#   'part': 3,
#   'exposure': 1,
#   'storyline': 1,
#   'collapse': 1,
#   'charity': 1,
#   'details': 1,
#   'career': 2,
#   'size': 1,
#   'quest': 1,
#   'task': 1,
#   'return': 1,
#   'trail': 1,
#   'Vicar': 1,
#   'creator': 1,
#   'backing': 1,
#   'remains': 1,
#   'host': 1,
#   'best': 4,
#   'supervisor': 1,
#   'husband': 1,
#   'aim': 1,
#   'rate': 3,
#   'chance': 2,
#   're-release': 1,
#   'head': 3,
#   'charges': 1,
#   'seriousness': 1,
#   'scale': 1,
#   'announcement': 1,
#   'star': 1,
#   'banks': 2,
#   'label': 1,
#   'event': 1,
#   'spell': 1,
#   'state': 5,
#   'type': 1,
#   'hands': 1,
#   'vocals': 1,
#   'badlands': 1,
#   'category': 1,
#   'experiences': 1,
#   'chagrin': 1,
#   'point': 2,
#   'colour': 1,
#   'branding': 1,
#   'existence': 1,
#   'debate': 1,
#   'status': 1,
#   'red-tape': 1,
#   'home': 1,
#   'heart': 2,
#   'pleasure': 1,
#   'release': 2,
#   'godfather': 1,
#   'exuberance': 1,
#   'Transmigration': 1,
#   'weekend': 2,
#   'loss': 1,
#   'space': 1,
#   'longevity': 1,
#   'advent': 1,
#   'battle': 1,
#   'Society': 1,
#   'conditions': 1,
#   'bows': 1,
#   'Fullness': 1,
#   'door': 1,
#   'advantage': 1,
#   'weight': 1,
#   'anniversary': 1,
#   'benchmarks': 1,
#   'induction': 1,
#   'Love': 1,
#   'shadows': 1,
#   'demands': 1,
#   'cast': 1,
#   'voice': 4,
#   'destruction': 1,
#   'backdrop': 1,
#   'implications': 1,
#   'Isle': 1,
#   'forest': 1,
#   'appetite': 1,
#   'kind': 2,
#   'sides': 1,
#   'ravages': 1,
#   'absence': 1,
#   'stature': 1,
#   'good': 1,
#   'stars': 1,
#   'butt': 1,
#   'mannerisms': 1,
#   'estate': 1,
#   'operation': 1,
#   'advance': 1,
#   'basis': 1,
#   'force': 1,
#   'themes': 1,
#   'unveiling': 1,
#   'papers': 1,
#   'wedding': 1,
#   'people': 1,
#   'introduction': 1,
#   'deportation': 1,
#   'kids': 1,
#   'Mice': 1,
#   'grearest': 1,
#   'pictures': 1,
#   'DVDs': 1,
#   'price': 2,
#   'parents': 1,
#   'safety': 1,
#   'thousands': 1,
#   'highlight': 1,
#   'shape': 1,
#   'Day': 1,
#   'Prince': 1,
#   'advice': 1,
#   'effect': 1,
#   'works': 1,
#   'ratings': 1,
#   'views': 1,
#   'year': 1,
#   'middle': 1,
#   'airing': 1,
#   'aftermath': 1,
#   'directors': 1,
#   'time': 1,
#   'rubble': 1,
#   'remake': 1,
#   'hero': 1,
#   'prospect': 1,
#   'bath': 1,
#   'exception': 1,
#   'transformation': 1,
#   'Order': 1,
#   'possibilities': 1,
#   'board': 1,
#   'mirror': 1,
#   'voices': 1,
#   'sale': 1,
#   'powers': 1,
#   'character': 1},
#  ('bicentennial', 'the'): {'of': 1},
#  ('of', 'birth'): {'the': 2},
#  ('birth', 'writer'): {'of': 1},
#  ('of', 'Hans'): {'writer': 1},
#  ('writer', 'Christian'): {'Hans': 1},
#  ('Hans', 'Andersen'): {'Christian': 3},
#  ('Christian', '.'): {'Andersen': 1},
#  ('Denmark', 'holding'): {'is': 1},
#  ('is', 'a'): {'holding': 1,
#   'of': 1,
#   'among': 1,
#   '``': 2,
#   'that': 1,
#   'about': 3,
#   'always': 1,
#   'also': 2,
#   'not': 4,
#   'in': 1,
#   'now': 2,
#   'promoting': 1,
#   'proving': 1,
#   'just': 2,
#   'asking': 1,
#   'surely': 1,
#   "n't": 1,
#   'running': 1,
#   'awaiting': 1,
#   'still': 1,
#   'create': 1},
#  ('holding', 'three-day'): {'a': 1},
#  ('a', 'celebration'): {'three-day': 1, '``': 1},
#  ('three-day', 'of'): {'celebration': 1},
#  ('celebration', 'the'): {'of': 1},
#  ('of', 'life'): {'the': 1,
#   'my': 3,
#   'urban': 1,
#   'her': 1,
#   'his': 2,
#   'surburban': 1},
#  ('life', 'the'): {'of': 1, 'into': 1, 'in': 2, 'is': 1},
#  ('of', 'fairy-tale'): {'the': 1},
#  ('the', 'author'): {'fairy-tale': 1},
#  ('fairy-tale', ','): {'author': 1},
#  ('author', 'with'): {',': 1},
#  (',', 'a'): {'with': 10,
#   'at': 2,
#   'about': 6,
#   'when': 2,
#   'drove': 1,
#   'in': 2,
#   'around': 1,
#   "''": 6,
#   'by': 1,
#   'is': 1,
#   'despite': 1,
#   'preferring': 2,
#   'setting': 1,
#   'and': 4,
#   'served': 1,
#   'while': 2,
#   'earning': 1,
#   'after': 2,
#   'thinks': 1,
#   'suffered': 1,
#   'including': 4,
#   'possibly': 1,
#   'caused': 2,
#   'been': 2,
#   'now': 1,
#   'following': 2,
#   'sending': 1,
#   'attracting': 2,
#   'particularly': 1,
#   'joins': 1,
#   'have': 2,
#   'gaining': 1,
#   'on': 1,
#   'where': 1,
#   'played': 2,
#   'features': 1,
#   'giving': 1,
#   'winning': 1,
#   'angering': 1,
#   'told': 1,
#   'begin': 1,
#   'under': 1,
#   'was': 2,
#   'making': 2,
#   'discovering': 1,
#   'marking': 1,
#   'plays': 1,
#   'got': 1,
#   'flashing': 1,
#   'over': 1,
#   'not': 1,
#   'singing': 1,
#   'as': 1,
#   'received': 1,
#   'citing': 1},
#  ('with', 'concert'): {'a': 1},
#  ('a', 'at'): {'concert': 3,
#   'fellow': 2,
#   'lecturer': 1,
#   'pap': 1,
#   'place': 1,
#   'swipe': 1,
#   'duet': 1,
#   'window': 1,
#   'teenager': 1,
#   'look': 1},
#  ('concert', 'Parken'): {'at': 1},
#  ('at', 'stadium'): {'Parken': 1},
#  ('Parken', 'on'): {'stadium': 1},
#  ('stadium', '2'): {'on': 1},
#  ('on', 'April'): {'2': 1, '5': 1, '18': 1, '17': 1, '21': 1, '4': 1},
#  ('2', '.'): {'April': 1, 'Wikid': 1, 'daughters': 1},
#  ('April', 'Other'): {'.': 1},
#  ('.', 'stars'): {'Other': 2,
#   'British': 1,
#   'Enterprise': 1,
#   'But': 1,
#   'Pop': 1,
#   'Hollywood': 1,
#   'It': 1},
#  ('Other', 'are'): {'stars': 1},
#  ('stars', 'expected'): {'are': 2},
#  ('are', 'to'): {'expected': 9,
#   'likely': 2,
#   'said': 3,
#   'estimated': 1,
#   'going': 3,
#   'preparing': 1,
#   'yet': 4,
#   'scheduled': 2,
#   'honoured': 1,
#   'given': 3,
#   'predicted': 1,
#   'subjected': 2,
#   'due': 3,
#   'keen': 1,
#   'well-known': 1,
#   'considered': 1,
#   "n't": 1,
#   'talking': 1,
#   'attempting': 1,
#   'trying': 3,
#   'privy': 2,
#   'unable': 1,
#   'set': 2,
#   'easy': 1,
#   'seen': 1,
#   'continuing': 1},
#  ('expected', 'join'): {'to': 1},
#  ('join', 'line-up'): {'the': 1},
#  ('the', 'in'): {'line-up': 1,
#   'category': 1,
#   'hammer': 1,
#   'greatest': 1,
#   'fall': 1,
#   'decline': 1,
#   'paintings': 1,
#   'show': 5,
#   'headlines': 1,
#   'world': 2,
#   'Oscars': 1,
#   'film': 2,
#   'day': 1,
#   'role': 3,
#   'event': 1,
#   'BBC': 2,
#   'changes': 1,
#   'latest': 1,
#   'year': 2,
#   'chart': 1,
#   'results': 1,
#   'outsider': 2,
#   'township': 1,
#   'runners-up': 2,
#   'church': 1,
#   'best': 1,
#   'ceremony': 1,
#   'war': 4,
#   'charts': 5,
#   'Children': 1,
#   '999th': 2,
#   'weekend': 1,
#   'rise': 1,
#   'studio': 1,
#   'premises': 1,
#   'sixth': 2,
#   'Music': 1,
#   'game': 2,
#   'Atlantic': 1,
#   'UK': 5,
#   'top': 2,
#   'fifth': 1,
#   'case': 1,
#   'public': 1,
#   'Pops': 1,
#   'brawl': 1,
#   'track': 1,
#   'single': 1,
#   'first': 2,
#   'instruments': 1,
#   'US': 6,
#   'stations': 1,
#   'World': 1,
#   'format': 1,
#   'closest': 1,
#   'Beanstalk': 1,
#   'series': 1,
#   'festivities': 1,
#   'fun': 1,
#   'next': 1,
#   'winner': 2,
#   'others': 1,
#   'festival': 2,
#   'perception': 1,
#   'creativity': 1,
#   'cameras': 1,
#   'T': 1,
#   'SECC': 1,
#   'better': 1,
#   'deal': 1,
#   'King': 1,
#   'nanny': 1,
#   'reduction': 1,
#   'book': 1,
#   'victims': 1,
#   'millennium': 1,
#   'mansion': 1,
#   'phrase': 1,
#   'nickname': 1,
#   'awards': 1,
#   'paparazzi': 1,
#   'road': 1,
#   'allegation': 1,
#   'films': 1,
#   'past': 1,
#   'Odeon': 1,
#   'Jackal': 1,
#   'stars': 1,
#   'company': 1,
#   'troubles': 1,
#   'Oscar': 1,
#   'court': 1,
#   'character': 1},
#  ('line-up', 'the'): {'in': 1, ',': 2, 'of': 1},
#  ('in', 'coming'): {'the': 2},
#  ('the', 'months'): {'coming': 1},
#  ('coming', ','): {'months': 1, 'forward': 1},
#  ('months', 'and'): {',': 1},
#  (',', 'the'): {'and': 22,
#   'at': 8,
#   'described': 1,
#   "''": 13,
#   'told': 3,
#   'in': 8,
#   'with': 24,
#   'beating': 2,
#   'scooped': 1,
#   'from': 6,
#   'said': 12,
#   'was': 7,
#   'launched': 1,
#   'during': 4,
#   'used': 1,
#   'accused': 1,
#   'where': 3,
#   'but': 12,
#   'suddenly': 1,
#   'then': 2,
#   'won': 3,
#   'including': 8,
#   'leads': 2,
#   'is': 8,
#   'recalled': 2,
#   'quoting': 2,
#   'Do': 2,
#   'throwing': 1,
#   'convulsed': 1,
#   'despite': 1,
#   'Beyond': 1,
#   'entering': 1,
#   'after': 3,
#   'when': 4,
#   'showing': 1,
#   'taking': 5,
#   'says': 3,
#   'while': 8,
#   'are': 1,
#   'gave': 1,
#   'received': 1,
#   'opens': 2,
#   'compiling': 2,
#   'made': 3,
#   'followed': 1,
#   '[': 1,
#   'added': 1,
#   'if': 1,
#   'entered': 1,
#   'so': 2,
#   'particularly': 1,
#   'topped': 2,
#   'were': 3,
#   'as': 1,
#   'toppling': 1,
#   'costs': 1,
#   'earned': 1,
#   'around': 1,
#   'following': 1,
#   'claim': 1,
#   'attended': 1,
#   'co-wrote': 2,
#   'earning': 1,
#   'behind': 1,
#   'which': 1,
#   'giving': 1,
#   'twice': 1,
#   'about': 3,
#   'for': 1,
#   'recognise': 1,
#   'saying': 1,
#   'reached': 1,
#   'booked': 1,
#   'over': 2,
#   'to': 3,
#   'prints': 1,
#   'contains': 1,
#   'providing': 1,
#   'winning': 2,
#   'Through': 1,
#   'getting': 1,
#   'On': 1,
#   'rejoined': 1,
#   'supported': 1,
#   'leading': 1,
#   'before': 1,
#   'of': 1,
#   'on': 2,
#   'celebrating': 1,
#   'reprise': 1,
#   'plays': 1,
#   'although': 1,
#   'Meet': 3,
#   'replaces': 1,
#   'probably': 1,
#   'given': 1,
#   'greeted': 1,
#   'dubbed': 1,
#   'include': 1,
#   'did': 1,
#   'losing': 1,
#   'or': 1,
#   'completed': 1,
#   'playing': 1,
#   'through': 1,
#   'exploring': 1},
#  ('and', 'Danish'): {'the': 1},
#  ('the', 'royal'): {'Danish': 1},
#  ('Danish', 'family'): {'royal': 1},
#  ('royal', 'will'): {'family': 1},
#  ('family', 'attend'): {'will': 1},
#  ('will', '.'): {'attend': 1, 'return': 1, 'understand': 1, 'be': 1, 'too': 1},
#  ('attend', '``'): {'.': 1},
#  ('.', 'Christian'): {'``': 1},
#  ('``', 'Andersen'): {'Christian': 1},
#  ('Christian', "'s"): {'Andersen': 1, 'community': 1},
#  ('Andersen', 'fairy'): {"'s": 1},
#  ("'s", 'tales'): {'fairy': 1},
#  ('fairy', 'are'): {'tales': 1},
#  ('tales', 'timeless'): {'are': 1},
#  ('are', 'and'): {'timeless': 1,
#   'weak': 1,
#   'forceful': 1,
#   'indicative': 1,
#   'oversensitive': 1,
#   'great': 1},
#  ('timeless', 'universal'): {'and': 1},
#  ('and', ','): {'universal': 1,
#   'Tender': 1,
#   'prostitution': 1,
#   'Warhol': 1,
#   'then': 1,
#   'grace': 1,
#   'kickboxing': 1,
#   'vision': 1,
#   'XDance': 1,
#   'Hollywood': 1,
#   'Staunton': 1,
#   'musical': 1,
#   'family': 2,
#   'screen': 1,
#   'Guy': 1,
#   'Seek': 4,
#   'Sideways': 1,
#   'yet': 1,
#   'Joey': 1,
#   'Travis': 1,
#   'songwriter': 1,
#   'Fears': 1,
#   'Jamelia': 1,
#   '0700': 1,
#   'Over': 1,
#   'Debussy': 1,
#   'battery': 1,
#   'skateboards': 1,
#   'UK': 1,
#   'ITV1': 2,
#   '80s': 1,
#   'understated': 1,
#   '60s': 1,
#   'Saunders': 1,
#   'television': 1,
#   'hungry': 1,
#   'Dec': 1,
#   'skill': 1,
#   'safety': 1,
#   '2004': 1,
#   'despair': 1,
#   'Sherry': 1,
#   'dad': 1,
#   'Greensleeves': 1,
#   'charismatic': 1,
#   'LSF': 1,
#   'Hip-Hop': 1,
#   '1956': 1,
#   'Pink': 1,
#   'raw': 1,
#   '1980': 1,
#   'Hallelujah': 1,
#   'London': 1,
#   'Napster': 1,
#   'piracy': 1,
#   'out': 1,
#   'screaming': 1,
#   'violence': 1,
#   'Motors': 1,
#   'competitions': 1,
#   'Nas': 1,
#   'China': 1,
#   'Germany': 1,
#   'English': 1,
#   'Phinnaeus': 1,
#   'love': 1,
#   'thinking': 1,
#   'spiritually': 1,
#   '1973': 1,
#   'overwhelmed': 1,
#   'Iris': 1,
#   'Elizabeth': 1,
#   'nominees': 1,
# ...
#  ('Robbie', "'"): {'Williams': 3},
#  ('Williams', 'autobiography'): {"'": 1},
#  ("'", 'Feel'): {'autobiography': 1},
#  ('autobiography', '.'): {'Feel': 1},
#  ('Feel', 'This'): {'.': 1},
#  ('.', 'year'): {'This': 15, 'Last': 17, 'The': 2, 'A': 1},
#  ('This', "'s"): {'year': 16, 'weekend': 1},
#  ('winner', 'Alice'): {',': 1},
#  (',', 'Sebold'): {'Alice': 1},
#  ('Alice', "'s"): {'Sebold': 1},
#  ('Sebold', 'The'): {"'s": 1},
#  ("'s", 'Lovely'): {'The': 1},
#  ('The', 'Bones'): {'Lovely': 1},
#  ('Lovely', ','): {'Bones': 2},
#  ('Bones', 'sold'): {',': 1},
#  (',', 'over'): {'sold': 1, 'taking': 1, 'kicking': 1},
#  ('sold', 'one'): {'over': 1, 'around': 1},
#  ('over', 'million'): {'one': 1},
#  ('one', '.'): {'million': 1,
#   'book': 1,
#   'genre': 1,
#   'works': 1,
#   'single': 1,
#   'thing': 1,
#   'place': 1},
#  ('million', 'Joseph'): {'.': 1},
#  ('.', "O'Connor"): {'Joseph': 1},
#  ('Joseph', "'s"): {"O'Connor": 1},
#  ("O'Connor", 'Star'): {"'s": 1},
#  ('Star', 'the'): {'of': 1, 'as': 1},
#  ('of', 'Sea'): {'the': 1},
#  ('the', 'came'): {'Sea': 1, 'merchants': 1, 'celebrities': 1, 'truce': 1},
#  ('Sea', 'second'): {'came': 1},
#  ('came', 'and'): {'second': 1},
#  ('second', 'saw'): {'and': 1},
#  ('and', 'sales'): {'saw': 1,
#   'video': 3,
#   'physical': 2,
#   'publishing': 2,
#   'total': 1,
#   'record': 1,
#   'merchandise': 1},
#  ('saw', 'increase'): {'sales': 1},
#  ('sales', 'by'): {'increase': 1, 'fell': 1, 'declined': 1},
#  ('increase', '350'): {'by': 1},
#  ('by', '%'): {'350': 1,
#   '10': 1,
#   '12': 2,
#   '20': 2,
#   '13.8': 1,
#   '1.3': 1,
#   '4.5': 1,
#   '50': 1},
#  ('350', '.'): {'%': 1},
#  ('%', 'The'): {'.': 2},
#  ('.', 'best'): {'The': 5, 'Their': 1},
#  ('The', 'read'): {'best': 1},
#  ('best', 'award'): {'read': 1,
#   'actor': 1,
#   'actress': 5,
#   'director': 4,
#   'film': 6,
#   'screenplay': 1,
#   'directing': 1},
#  ('read', ','): {'award': 1, 'it': 1, 'Proust': 1},
#  ('award', 'on'): {',': 1},
#  (',', 'Richard'): {'on': 1, 'said': 1},
#  ('on', 'Madeley'): {'Richard': 1},
#  ('Richard', 'and'): {'Madeley': 1, 'Eyre': 1, 'McCourt': 1, 'Adler': 1},
#  ('Madeley', 'Judy'): {'and': 1},
#  ('and', 'Finnigan'): {'Judy': 1},
#  ('Judy', "'s"): {'Finnigan': 1},
#  ('Finnigan', 'Channel'): {"'s": 1},
#  ("'s", '4'): {'Channel': 2},
#  ('Channel', 'show'): {'4': 7},
#  ('4', ','): {'show': 2},
#  ('show', 'is'): {',': 1, 'that': 1},
#  (',', 'part'): {'is': 1, 'as': 1, 'in': 1},
#  ('is', 'of'): {'part': 2,
#   'typical': 1,
#   'one': 21,
#   'host': 1,
#   'recognition': 1,
#   'memories': 1,
#   'jealous': 1,
#   'characteristic': 1,
#   'more': 1,
#   'critical': 1,
#   'plenty': 1},
#  ('part', 'the'): {'of': 14, 'in': 2},
#  ('of', 'British'): {'the': 2,
#   'other': 1,
#   'disappointed': 1,
#   '24': 1,
#   'honouring': 1},
#  ('the', 'Book'): {'British': 1, 'Whitbread': 1, 'London': 1},
#  ('British', 'Awards'): {'Book': 1, 'Film': 1, 'Comedy': 2},
#  ('Book', '.'): {'Awards': 2, 'Prizes': 1},
#  ('Awards', 'David'): {'.': 1},
#  ('.', 'Mitchell'): {'David': 1},
#  ('David', "'s"): {'Mitchell': 1},
#  ('Mitchell', 'Booker-shortlisted'): {"'s": 1},
#  ("'s", 'novel'): {'Booker-shortlisted': 1,
#   'fourth': 2,
#   'first': 1,
#   'best-selling': 2,
#   'fantasy': 1},
#  ('Booker-shortlisted', ','): {'novel': 1},
#  ('novel', 'Cloud'): {',': 1},
#  (',', 'Atlas'): {'Cloud': 1},
#  ('Cloud', ','): {'Atlas': 1},
#  ('Atlas', 'makes'): {',': 1},
#  (',', 'it'): {'makes': 1,
#   'says': 1,
#   'and': 7,
#   'admitted': 1,
#   'but': 12,
#   'ensuring': 1,
#   'when': 3,
#   'saying': 4,
#   'as': 2,
#   'whether': 1,
#   'expecting': 1,
#   'said': 4,
#   'making': 2,
#   'made': 1,
#   'where': 2,
#   'that': 1,
#   'claiming': 1,
#   'all': 1,
#   'because': 2,
#   'however': 1,
#   'if': 1,
#   'after': 1,
#   'be': 1,
#   'could': 1,
#   'so': 1,
#   'since': 1,
#   'uses': 1,
#   'hoping': 1},
#  ('makes', 'into'): {'it': 1},
#  ('it', 'this'): {'into': 1, 'safe': 2},
#  ('into', 'year'): {'this': 1},
#  ('year', 'top'): {"'s": 1, 'to': 1},
#  ("'s", '10'): {'top': 1},
#  ('top', 'along'): {'10': 1},
#  ('10', 'with'): {'along': 1},
#  ('along', 'several'): {'with': 1},
#  ('with', 'lesser'): {'several': 1},
#  ('several', 'known'): {'lesser': 1},
#  ('lesser', 'works'): {'known': 1},
#  ('known', '.'): {'works': 1},
#  ('``', "'s"): {'There': 10,
#   'It': 53,
#   'Saddam': 1,
#   'He': 2,
#   'That': 4,
#   'there': 1,
#   'Where': 1,
#   'No-one': 1,
#   'devil': 1,
#   'Here': 1,
#   '50': 1,
#   'What': 1,
#   '2004': 1,
#   'Everybody': 1},
#  ('There', 'no'): {"'s": 3, 'were': 2, 'is': 7, 'was': 1},
#  ("'s", 'doubt'): {'no': 1},
#  ('no', 'that'): {'doubt': 1, 'question': 2},
#  ('doubt', 'this'): {'that': 1},
#  ('that', 'year'): {'this': 1},
#  ('year', 'selection'): {"'s": 1},
#  ('selection', 'book'): {'of': 1},
#  ('of', 'club'): {'book': 1},
#  ('book', 'entries'): {'club': 1},
#  ('club', 'is'): {'entries': 1},
#  ('entries', 'the'): {'is': 1},
#  ('is', 'best'): {'the': 7},
#  ('the', 'yet'): {'best': 2},
#  ('best', '.'): {'yet': 2,
#   'director': 1,
#   'actress': 5,
#   'film': 4,
#   'documentary': 2,
#   'sound': 2,
#   'actor': 1,
#   'comedy': 1,
#   'album': 2,
#   'male': 1,
#   'song': 1,
#   'record': 1,
#   'video': 1,
#   'ignored': 1,
#   'choreography': 1,
#   'movie': 1,
#   'editing': 1,
#   'make-up': 1},
#  ('yet', 'If'): {'.': 1},
#  ('.', 'anything'): {'If': 2},
#  ('If', ','): {'anything': 1, 'Lemar': 1, 'convicted': 1},
#  ('anything', 'the'): {',': 1, 'from': 1},
#  (',', 'choice'): {'the': 1},
#  ('the', 'is'): {'choice': 1,
#   'musical': 1,
#   'running': 1,
#   'play': 1,
#   'signature': 1,
#   'sale': 1,
#   'trend': 1,
#   'gallery': 2,
#   'competition': 1,
#   'country': 1,
#   'festival': 2,
#   'US': 1,
#   'audience': 1,
#   'sequel': 1,
#   'trial': 1,
#   'action': 1,
#   'movie': 3,
#   'reality': 1,
#   'season': 1,
#   'story': 1,
#   'film': 3,
#   'issue': 1,
#   'song': 2,
#   'thing': 1,
#   'single': 1,
#   'contestant': 1,
#   'Pops': 1,
#   'BBC': 1,
#   'fact': 1,
#   'government': 1,
#   'list': 1,
#   'time': 1,
#   'fuss': 1,
#   'name': 1,
#   'BPI': 1,
#   'event': 1,
#   'market': 2,
#   'orchestra': 1,
#   'ceremony': 1,
#   'show': 1,
#   'dollar': 1,
#   'driving': 1,
#   'workforce': 1,
#   'past': 1,
#   'reference': 1},
#  ('choice', 'even'): {'is': 1},
#  ('is', 'wider'): {'even': 1},
#  ('even', 'than'): {'wider': 1},
#  ('wider', 'last'): {'than': 1},
#  ('than', 'time'): {'last': 1},
#  ('last', ','): {'time': 2,
#   'year': 22,
#   'Thursday': 1,
#   'week': 2,
#   'September': 3,
#   'album': 3,
#   'January': 1,
#   'October': 1,
#   'single': 1,
#   'month': 2},
#  ('time', "''"): {',': 8, '.': 7},
#  ("''", 'Madeley'): {'said': 1},
#  ('Madeley', '``'): {'.': 1},
#  ('.', 'It'): {'``': 65, "''": 2},
#  ('``', 'was'): {'It': 8,
#   'Belfast': 1,
#   'There': 1,
#   'Ossie': 4,
#   'Bob': 2,
#   'I': 6,
#   'He': 5,
#   'Anna': 1,
#   'This': 1,
#   'She': 3,
#   'Hollywood': 1},
#  ('It', 'very'): {'was': 2, "'s": 6},
#  ('was', 'hard'): {'very': 1},
#  ('very', 'to'): {'hard': 3, 'excited': 1, 'fortunate': 1},
#  ('hard', 'follow'): {'to': 1},
#  ('to', 'last'): {'follow': 1, '81': 1},
#  ('follow', 'year'): {'last': 1},
#  ('last', "'s"): {'year': 14,
#   'week': 4,
#   'month': 1,
#   'Sunday': 1,
#   'weekend': 1},
#  ('year', 'extremely'): {"'s": 1},
#  ("'s", 'successful'): {'extremely': 1, 'most': 1},
#  ('extremely', 'list'): {'successful': 1},
#  ('successful', ','): {'list': 1, 'year': 1},
#  ('list', 'but'): {',': 1},
#  (',', 'we'): {'but': 6,
#   'what': 1,
#   'as': 2,
#   'and': 7,
#   'because': 1,
#   'so': 4,
#   'then': 1,
#   'would': 1},
#  ('but', 'think'): {'we': 1, 'many': 1},
#  ('we', 'this'): {'think': 1},
#  ('think', 'year'): {'this': 2},
#  ('year', 'books'): {"'s": 1},
#  ("'s", 'will'): {'books': 1,
#   ',': 1,
#   'coverage': 1,
#   'bags': 1,
#   'festival': 2,
#   'chart': 1,
#   'show': 1,
#   'awards': 1,
#   'comedy': 1},
#  ('books', 'do'): {'will': 1},
#  ('will', 'even'): {'do': 1, 'be': 1},
#  ('do', 'better'): {'even': 1},
#  ('even', ','): {'better': 2},
#  ('better', "''"): {',': 3},
#  ("''", 'Richard'): {'said': 1, 'Co-star': 1},
#  ('said', 'and'): {'Richard': 1, 'Stiller': 1, 'he': 1, 'it': 1},
#  ('and', 'executive'): {'Judy': 1, 'chief': 2},
#  ('Judy', 'producer'): {'executive': 1},
#  ('executive', 'Amanda'): {'producer': 1},
#  ('producer', 'Ross'): {'Amanda': 1},
#  ('Amanda', '.'): {'Ross': 1, 'Wingfield': 1},
#  ('Ross', '``'): {'.': 4},
#  ('.', 'We'): {'``': 74, 'Why': 1},
#  ('``', 'were'): {'We': 7, 'They': 1, 'Studios': 1},
#  ('We', 'spoiled'): {'were': 1},
#  ('were', 'for'): {'spoiled': 1,
#   'voted': 1,
#   'married': 1,
#   'nominated': 4,
#   'asked': 2,
#   'not': 1,
#   'chosen': 1,
#   'calls': 1,
#   'made': 1},
#  ('spoiled', 'choice'): {'for': 1},
#  ('for', 'and'): {'choice': 1,
#   'Cruel': 1,
#   'Jesus': 1,
#   'stage': 1,
#   "L'Equipier": 1,
#   'dramas': 1,
#   'musicals': 1,
#   'me': 1,
#   'Ant': 1,
#   'writing': 1,
#   'obscene': 1,
#   'itself': 1,
#   'assault': 1,
#   'artist': 1,
#   'Confessions': 1,
#   '2004': 1,
#   'myself': 1,
#   'Secrets': 2,
#   'DiCaprio': 1,
#   'soprano': 1,
#   'Edward': 1,
#   'Ray': 1,
#   'Kinsey': 1},
#  ('choice', 'it'): {'and': 1},
#  ('and', 'was'): {'it': 4,
#   'preacher': 1,
#   'Moore': 1,
#   'she': 3,
#   'there': 3,
#   'so': 1,
#   'he': 3,
#   'I': 1,
#   'Demons': 1},
#  ('it', 'tough'): {'was': 1},
#  ('was', 'getting'): {'tough': 1, 'not': 1, "n't": 1},
#  ('tough', 'down'): {'getting': 1},
#  ('getting', 'to'): {'down': 1, 'ready': 1},
#  ('down', 'only'): {'to': 1},
#  ('to', '10'): {'only': 1},
#  ('only', 'from'): {'10': 1},
#  ('10', 'the'): {'from': 1, 'in': 1},
#  ('from', '301'): {'the': 1},
#  ('the', 'submitted'): {'301': 1},
#  ('301', '.'): {'submitted': 1},
#  ('submitted', "''"): {'.': 1},
#  ('Poppins', 'gets'): {'musical': 1},
#  ('musical', 'flying'): {'gets': 1},
#  ('gets', 'start'): {'flying': 1},
#  ('The', 'adaptation'): {'stage': 1, 'film': 1},
#  ('stage', 'of'): {'adaptation': 1,
#   'adaptations': 1,
#   'production': 1,
#   'version': 2},
#  ('adaptation', 'children'): {'of': 1},
#  ('children', 'film'): {"'s": 2},
#  ("'s", 'Mary'): {'film': 1},
#  ('film', 'Poppins'): {'Mary': 1},
#  ('Mary', 'has'): {'Poppins': 1},
#  ('Poppins', 'had'): {'has': 1},
#  ('has', 'its'): {'had': 1,
#   'spawned': 1,
#   'surpassed': 2,
#   'taken': 1,
#   'cancelled': 1},
#  ('had', 'opening'): {'its': 1},
#  ('its', 'night'): {'opening': 1},
#  ('opening', 'in'): {'night': 1},
#  ('night', 'London'): {'in': 1},
#  ('London', 'West'): {"'s": 4},
#  ("'s", 'End'): {'West': 5},
#  ('West', '.'): {'End': 3},
#  ('Sir', 'Mackintosh'): {'Cameron': 4},
#  ('Cameron', "'s"): {'Mackintosh': 2},
#  ('Mackintosh', 'lavish'): {"'s": 1},
#  ("'s", 'production'): {'lavish': 1, 'own': 1},
#  ('lavish', ','): {'production': 1, 'ceremony': 1},
#  ('production', 'which'): {',': 2},
#  (',', 'has'): {'which': 16,
#   'who': 23,
#   'Swank': 2,
#   'he': 2,
#   'it': 5,
#   'but': 4,
#   'EastEnders': 1,
#   'and': 5,
#   'research': 1,
#   'there': 3,
#   'Charlie': 1,
#   'Hoffmann': 1,
#   'Britain': 1,
#   'Arnold': 1},
#  ('which', 'cost'): {'has': 1, 'reportedly': 1},
#  ('has', '£9m'): {'cost': 1},
#  ('cost', 'to'): {'£9m': 2},
#  ('£9m', 'bring'): {'to': 2},
#  ('to', 'to'): {'bring': 2,
#   'how': 1,
#   'campaign': 1,
#   'Yeats': 1,
#   'listen': 2,
#   'want': 3,
#   'add': 2,
#   'Willis': 1,
#   'go': 3,
#   'do': 1,
#   'refer': 2,
#   'travel': 2,
#   'return': 3,
#   'commit': 1,
#   'send': 1,
#   'appeal': 1,
#   'offer': 1,
#   'say': 1,
#   'respond': 3,
#   'refuse': 1,
#   'attach': 1,
#   'pay': 1,
#   'fans': 1,
#   'London': 1,
#   'fight': 1,
#   'come': 1,
#   'April': 1,
#   'try': 1},
#  ('bring', 'the'): {'to': 2, 'in': 1, 'up': 1},
#  ('to', 'stage'): {'the': 9, 'centre': 2},
#  ('stage', 'was'): {',': 2, 'act': 1},
#  (',', 'given'): {'was': 1, 'are': 2},
#  ('given', '10-minute'): {'a': 1},
#  ('a', 'standing'): {'10-minute': 1},
#  ('10-minute', 'ovation'): {'standing': 1},
#  ('standing', '.'): {'ovation': 1},
#  ('ovation', 'Lead'): {'.': 1},
#  ('.', 'actress'): {'Lead': 1, 'British': 2, 'Chinese': 2, 'UK': 2, 'The': 1},
#  ('Lead', 'Laura'): {'actress': 1},
#  ('actress', 'Michelle'): {'Laura': 1},
#  ('Laura', 'Kelly'): {'Michelle': 4},
#  ('Michelle', 'soared'): {'Kelly': 1},
#  ('Kelly', 'over'): {'soared': 1},
#  ('soared', 'the'): {'over': 1, 'to': 1, 'past': 1},
#  ('over', 'heads'): {'the': 1},
#  ('heads', 'the'): {'of': 1},
#  ('of', 'audience'): {'the': 8},
#  ('the', 'holding'): {'audience': 1},
#  ('audience', 'the'): {'holding': 1, 'at': 2, 'in': 1, 'for': 1},
#  ('holding', 'nanny'): {'the': 1},
#  ('nanny', 'trademark'): {"'s": 1},
#  ("'s", 'umbrella'): {'trademark': 1},
#  ('trademark', '.'): {'umbrella': 1},
#  ('umbrella', 'Technical'): {'.': 1},
#  ('.', 'hitches'): {'Technical': 1},
#  ('Technical', 'had'): {'hitches': 1},
#  ('hitches', 'prevented'): {'had': 1},
#  ('had', 'Mary'): {'prevented': 1},
#  ('prevented', 'Poppins'): {'Mary': 1},
#  ('Mary', "'"): {'Poppins': 2},
#  ('Poppins', 'flight'): {"'": 1},
#  ("'", 'into'): {'flight': 1},
#  ('flight', 'the'): {'into': 1},
#  ('into', 'auditorium'): {'the': 1},
#  ('the', 'during'): {'auditorium': 1,
#   'industry': 1,
#   'piano': 1,
#   'singer': 1,
#   'UK': 1},
#  ('auditorium', 'preview'): {'during': 1},
#  ('during', 'performances'): {'preview': 1},
#  ('preview', '.'): {'performances': 1},
#  ('performances', 'A'): {'.': 1},
#  ('.', 'number'): {'A': 1, 'The': 2, 'At': 2},
#  ('number', 'celebrities'): {'of': 1},
#  ('of', 'turned'): {'celebrities': 1},
#  ('celebrities', 'out'): {'turned': 1},
#  ('turned', 'for'): {'out': 1},
#  ('out', 'the'): {'for': 3,
#   'of': 12,
#   'in': 8,
#   'all': 2,
#   'on': 5,
#   'among': 1,
#   'across': 1,
#   'and': 1,
#   'by': 2,
#   'at': 2,
#   'At': 1},
#  ('for', 'musical'): {'the': 2, 'best': 2, 'a': 2, 'Rings': 1},
#  ('musical', 'premiere'): {"'s": 1},
#  ('premiere', 'including'): {',': 1},
#  (',', 'actress'): {'including': 3, 'but': 1},
#  ('including', 'Barbara'): {'actress': 1},
#  ('actress', 'Windsor'): {'Barbara': 1},
#  ('Barbara', ','): {'Windsor': 1},
#  ('Windsor', 'comic'): {',': 1},
#  (',', 'Graham'): {'comic': 1},
#  ('comic', 'Norton'): {'Graham': 1},
#  ('Graham', 'and'): {'Norton': 1},
#  ('Norton', 'Sir'): {'and': 1},
#  ('and', 'Richard'): {'Sir': 1},
#  ('Sir', 'Attenborough'): {'Richard': 1},
#  ('Richard', '.'): {'Attenborough': 1, 'III': 1},
#  ('show', 'director'): {"'s": 2},
#  ("'s", 'Richard'): {'director': 1, ',': 1},
#  ('director', 'Eyre'): {'Richard': 1},
#  ('Richard', 'issued'): {'Eyre': 1},
#  ('Eyre', 'a'): {'issued': 1},
#  ('issued', 'warning'): {'a': 1},
#  ('a', 'earlier'): {'warning': 1},
#  ('warning', 'in'): {'earlier': 1},
#  ('earlier', 'the'): {'in': 3},
#  ('in', 'week'): {'the': 2},
#  ('the', 'that'): {'week': 2,
#   'impression': 1,
#   'people': 1,
#   'fact': 10,
#   'few': 1,
#   'choices': 2,
#   'battles': 2,
#   'magazine': 1,
#   'system': 1,
#   'luminosity': 1,
#   'films': 2,
#   'hope': 2,
#   'year': 1,
#   'stereotypes': 1,
#   'chemistry': 2,
#   'track': 1,
#   'shot': 1,
#   'two': 1,
#   'news': 1,
#   'eccentricity': 1,
#   'dysfunctions': 1,
#   'episodes': 1,
#   'tunes': 1,
#   'room': 1,
#   'way': 2,
#   'talent': 1,
#   'point': 1,
#   'soul': 1,
#   'tributes': 1,
#   'proposition': 1,
#   'acts': 1,
#   'Park': 1,
#   'viewers': 1,
#   'things': 1,
#   'show': 1,
#   'stage': 1,
#   'competition': 1,
#   'depression': 1,
#   'prospect': 1,
#   'film': 1,
#   'children': 1,
#   'court': 2,
#   '70s': 1,
#   'links': 1},
#  ('week', 'the'): {'that': 1, 'in': 1, 'of': 1, '-': 1, 'as': 1, ',': 1},
#  ('that', 'show'): {'the': 1},
#  ('the', 'was'): {'show': 1,
#   'idea': 1,
#   'Phoenix': 1,
#   'title': 1,
#   'service': 2,
#   'film': 7,
#   'injury': 1,
#   'past': 1,
#   'King': 1,
#   'car': 1,
#   'charts': 1,
#   'woman': 1,
#   'band': 1,
#   'result': 1,
#   'project': 1,
#   'school': 1,
#   'song': 2,
#   'Government': 1,
#   'burglar': 1,
#   'officers': 1,
#   'album': 1,
#   'list': 2,
#   'auction': 1,
#   'recipient': 1,
#   'pieces': 1,
#   'Pops': 2,
#   'musical': 1,
#   'station': 1,
#   'series': 1,
#   'comedian': 1,
#   'government': 1,
#   'line-up': 2,
#   'record': 1,
#   'pressure': 1,
#   'Wire': 1,
#   'situation': 1,
#   'video': 1,
#   'newcomer': 1,
#   'interview': 1,
#   'rapper': 1,
#   'SECC': 1,
#   'ceremony': 1,
#   'drop': 1,
#   'teenager': 1,
#   'hero': 1,
#   'Nog': 1,
#   'night': 1,
#   'move': 1,
#   'leaflet': 1,
#   'year': 1,
#   'case': 1},
#  ('show', 'unsuitable'): {'was': 1},
#  ('was', 'for'): {'unsuitable': 1,
#   'known': 2,
#   'given': 1,
#   'unavailable': 1,
#   'hailed': 1,
#   'nominated': 8,
#   ',': 1,
#   'arrested': 1,
#   'undergoing': 1,
#   'voted': 3,
#   'due': 1,
#   'appropriate': 1,
#   'need': 1,
#   'ripe': 1,
#   'shortlisted': 1,
#   'sold': 1,
#   'time': 1,
#   'best': 1,
#   'honoured': 1,
#   'guilty': 1,
#   'missing': 1,
#   'true': 1,
#   'reserved': 1,
#   'called': 1,
#   'notorious': 1},
#  ...}

# %%
# normalize probabilities
for key, d in probs.items():
  # d should represent a distribution
  total = sum(d.values())
  for k, v in d.items():
    d[k] = v / total

# %%
probs
# Out:
# {('Gallery', 'interactive'): {'unveils': 1.0},
#  ('unveils', 'tree'): {'interactive': 1.0},
#  ('A', 'tree'): {'Christmas': 1.0},
#  ('Christmas', 'that'): {'tree': 1.0},
#  ('tree', 'can'): {'that': 1.0},
#  ('that', 'receive'): {'can': 1.0},
#  ('can', 'text'): {'receive': 1.0},
#  ('receive', 'messages'): {'text': 1.0},
#  ('text', 'has'): {'messages': 1.0},
#  ('messages', 'been'): {'has': 1.0},
#  ('has', 'unveiled'): {'been': 1.0},
#  ('been', 'at'): {'unveiled': 0.125,
#   'shown': 0.125,
#   'estimated': 0.125,
#   'difficult': 0.125,
#   'surprised': 0.125,
#   'announced': 0.125,
#   'honoured': 0.25},
#  ('unveiled', 'London'): {'at': 1.0},
#  ('at', "'s"): {'London': 0.2972972972972973,
#   'Versace': 0.02702702702702703,
#   'Sotheby': 0.02702702702702703,
#   'Sunday': 0.10810810810810811,
#   'Hollywood': 0.05405405405405406,
#   'Grauman': 0.02702702702702703,
#   'Israel': 0.05405405405405406,
#   'Glasgow': 0.02702702702702703,
#   'Scotland': 0.05405405405405406,
#   'Dublin': 0.02702702702702703,
#   'Guernsey': 0.02702702702702703,
#   'MTV': 0.02702702702702703,
#   'Oxfam': 0.02702702702702703,
#   'France': 0.02702702702702703,
#   'Wednesday': 0.02702702702702703,
#   '1985': 0.02702702702702703,
#   'Sadler': 0.05405405405405406,
#   'Toronto': 0.02702702702702703,
#   'Bristol': 0.02702702702702703,
#   'June': 0.02702702702702703},
#  ('London', 'Tate'): {"'s": 1.0},
#  ("'s", 'Britain'): {'Tate': 1.0},
#  ('Tate', 'art'): {'Britain': 1.0},
#  ('Britain', 'gallery'): {'art': 1.0},
#  ('art', '.'): {'gallery': 0.5, 'colleges': 0.5},
#  ('The', 'has'): {'spruce': 0.022727272727272728,
#   'book': 0.045454545454545456,
#   'exhibition': 0.022727272727272728,
#   'film': 0.1590909090909091,
#   'Aviator': 0.1590909090909091,
#   'Fockers': 0.022727272727272728,
#   'star': 0.022727272727272728,
#   'school': 0.022727272727272728,
#   'government': 0.045454545454545456,
#   '64-year-old': 0.022727272727272728,
#   'process': 0.022727272727272728,
#   'track': 0.022727272727272728,
#   'UK': 0.045454545454545456,
#   'show': 0.045454545454545456,
#   'programme': 0.022727272727272728,
#   'BBC': 0.045454545454545456,
#   'Guardian': 0.022727272727272728,
#   'band': 0.022727272727272728,
#   'Brits': 0.045454545454545456,
#   'US': 0.045454545454545456,
#   'Producers': 0.022727272727272728,
#   'decision': 0.022727272727272728,
#   'ceremony': 0.022727272727272728,
#   'Baftas': 0.022727272727272728,
#   'Louvre': 0.022727272727272728},
#  ('spruce', 'an'): {'has': 1.0},
#  ('has', 'antenna'): {'an': 1.0},
#  ('an', 'which'): {'antenna': 0.5, 'aria': 0.5},
#  ('antenna', 'can'): {'which': 1.0},
#  ('which', 'receive'): {'can': 1.0},
#  ('can', 'Bluetooth'): {'receive': 1.0},
#  ('receive', 'texts'): {'Bluetooth': 1.0},
#  ('Bluetooth', 'sent'): {'texts': 1.0},
#  ('texts', 'by'): {'sent': 1.0},
#  ('sent', 'visitors'): {'by': 1.0},
#  ('by', 'to'): {'visitors': 0.25,
#   'trying': 0.25,
#   '600,000': 0.25,
#   'midnight': 0.25},
#  ('visitors', 'the'): {'to': 0.3333333333333333,
#   'made': 0.3333333333333333,
#   'through': 0.3333333333333333},
#  ('to', 'Tate'): {'the': 1.0},
#  ('the', '.'): {'Tate': 0.0021141649048625794,
#   'festivities': 0.0021141649048625794,
#   'UK': 0.02536997885835095,
#   'judges': 0.004228329809725159,
#   'World': 0.004228329809725159,
#   'award': 0.008456659619450317,
#   'Church': 0.0021141649048625794,
#   'Bishop': 0.0021141649048625794,
#   'BBC': 0.012684989429175475,
#   'country': 0.004228329809725159,
#   'back': 0.004228329809725159,
#   'sale': 0.0021141649048625794,
#   'Whitbread': 0.0021141649048625794,
#   'Year': 0.0021141649048625794,
#   'shortlist': 0.0021141649048625794,
#   'artists': 0.004228329809725159,
#   'show': 0.03805496828752643,
#   'west': 0.0021141649048625794,
#   'ground': 0.004228329809725159,
#   'discipline': 0.0021141649048625794,
#   'future': 0.012684989429175475,
#   'years': 0.004228329809725159,
#   'problem': 0.0021141649048625794,
#   'world': 0.03171247357293869,
#   'censors': 0.0021141649048625794,
#   '1920s': 0.0021141649048625794,
#   'US': 0.042283298097251586,
#   'series': 0.019027484143763214,
#   'public': 0.010570824524312896,
#   'attendance': 0.0021141649048625794,
#   'war': 0.004228329809725159,
#   'film': 0.03171247357293869,
#   '1980s': 0.004228329809725159,
#   'mind': 0.0021141649048625794,
#   'cinema': 0.0021141649048625794,
#   'book': 0.004228329809725159,
#   'deadline': 0.0021141649048625794,
#   'industry': 0.006342494714587738,
#   'movie': 0.006342494714587738,
#   '1600s': 0.0021141649048625794,
#   'campaign': 0.004228329809725159,
#   'project': 0.010570824524312896,
#   'night': 0.014799154334038054,
#   'Oscars': 0.019027484143763214,
#   'festival': 0.010570824524312896,
#   'eulogy': 0.004228329809725159,
#   'chart': 0.0021141649048625794,
#   'King': 0.004228329809725159,
#   'year': 0.019027484143763214,
#   'internet': 0.0021141649048625794,
#   'Sun': 0.0021141649048625794,
#   'firm': 0.0021141649048625794,
#   'injuries': 0.0021141649048625794,
#   'ceremony': 0.023255813953488372,
#   'camera': 0.004228329809725159,
#   'scenes': 0.0021141649048625794,
#   'bombings': 0.0021141649048625794,
#   'extras': 0.0021141649048625794,
#   'tale': 0.0021141649048625794,
#   'novel': 0.0021141649048625794,
#   'Bounty': 0.0021141649048625794,
#   'Netherlands': 0.0021141649048625794,
#   'politician': 0.0021141649048625794,
#   'bump': 0.0021141649048625794,
#   'Rings': 0.0021141649048625794,
#   'middle': 0.0021141649048625794,
#   'mainstream': 0.008456659619450317,
#   'biopic': 0.0021141649048625794,
#   'premiere': 0.0021141649048625794,
#   'Kranks': 0.004228329809725159,
#   'field': 0.004228329809725159,
#   'Dead': 0.0021141649048625794,
#   'effects': 0.0021141649048625794,
#   'voters': 0.0021141649048625794,
#   'deliberations': 0.004228329809725159,
#   'count': 0.0021141649048625794,
#   'outsider': 0.004228329809725159,
#   'event': 0.019027484143763214,
#   'Waterfront': 0.0021141649048625794,
#   'Festival': 0.0021141649048625794,
#   'books': 0.0021141649048625794,
#   'studio': 0.004228329809725159,
#   'Killers': 0.004228329809725159,
#   'concert': 0.0021141649048625794,
#   'poll': 0.0021141649048625794,
#   'case': 0.006342494714587738,
#   'head': 0.0021141649048625794,
#   'cover': 0.0021141649048625794,
#   'CD': 0.0021141649048625794,
#   'charges': 0.004228329809725159,
#   'shows': 0.0021141649048625794,
#   'spokesman': 0.0021141649048625794,
#   'track': 0.0021141649048625794,
#   'cancer': 0.0021141649048625794,
#   'legend': 0.0021141649048625794,
#   '70s': 0.0021141649048625794,
#   'floor': 0.0021141649048625794,
#   'album': 0.0021141649048625794,
#   'complaint': 0.004228329809725159,
#   'Papas': 0.0021141649048625794,
#   'top': 0.004228329809725159,
#   'morning': 0.0021141649048625794,
#   'music': 0.004228329809725159,
#   'masses': 0.0021141649048625794,
#   'taxpayer': 0.0021141649048625794,
#   'band': 0.004228329809725159,
#   'DJ': 0.0021141649048625794,
#   'headliners': 0.0021141649048625794,
#   'stage': 0.004228329809725159,
#   'Hoople': 0.004228329809725159,
#   'burglary': 0.0021141649048625794,
#   'window': 0.0021141649048625794,
#   'Bunnymen': 0.004228329809725159,
#   'Mic': 0.0021141649048625794,
#   'scheme': 0.0021141649048625794,
#   'issues': 0.0021141649048625794,
#   'prosecution': 0.0021141649048625794,
#   'Pops': 0.006342494714587738,
#   'auction': 0.0021141649048625794,
#   'time': 0.006342494714587738,
#   'Sugababes': 0.0021141649048625794,
#   'continent': 0.0021141649048625794,
#   'charity': 0.004228329809725159,
#   'Mack': 0.0021141649048625794,
#   'bank': 0.004228329809725159,
#   'money': 0.006342494714587738,
#   'schedule': 0.0021141649048625794,
#   'zeitgeist': 0.0021141649048625794,
#   'stars': 0.004228329809725159,
#   'murder': 0.0021141649048625794,
#   'ratings': 0.004228329809725159,
#   'Atlantic': 0.006342494714587738,
#   'suburbs': 0.0021141649048625794,
#   'originals': 0.004228329809725159,
#   'bottom': 0.0021141649048625794,
#   'Blind': 0.0021141649048625794,
#   'stadium': 0.0021141649048625794,
#   'pipeline': 0.0021141649048625794,
#   'print': 0.0021141649048625794,
#   'tsunami': 0.0021141649048625794,
#   'site': 0.0021141649048625794,
#   'movies': 0.0021141649048625794,
#   'vote': 0.004228329809725159,
#   'winner': 0.006342494714587738,
#   'Olympics': 0.0021141649048625794,
#   'findings': 0.0021141649048625794,
#   'episode': 0.0021141649048625794,
#   'original': 0.0021141649048625794,
#   'agreement': 0.0021141649048625794,
#   'camp': 0.0021141649048625794,
#   'service': 0.0021141649048625794,
#   'past': 0.004228329809725159,
#   'decision': 0.0021141649048625794,
#   'comedian': 0.0021141649048625794,
#   'truth': 0.0021141649048625794,
#   'council': 0.0021141649048625794,
#   'channel': 0.0021141649048625794,
#   'radio': 0.0021141649048625794,
#   'transmission': 0.0021141649048625794,
#   'Ugly': 0.0021141649048625794,
#   'way': 0.0021141649048625794,
#   'magazine': 0.0021141649048625794,
#   'programme': 0.0021141649048625794,
#   'house': 0.006342494714587738,
#   'station': 0.0021141649048625794,
#   '1970s': 0.0021141649048625794,
#   'Bahamas': 0.0021141649048625794,
#   'charts': 0.0021141649048625794,
#   'Radio': 0.0021141649048625794,
#   'city': 0.0021141649048625794,
#   'crowd': 0.0021141649048625794,
#   'controversy': 0.0021141649048625794,
#   'awards': 0.0021141649048625794,
#   'disappearance': 0.0021141649048625794,
#   'truce': 0.0021141649048625794,
#   'bone': 0.0021141649048625794,
#   'Brits': 0.0021141649048625794,
#   'list': 0.006342494714587738,
#   'boxes': 0.0021141649048625794,
#   'minute': 0.0021141649048625794,
#   'day': 0.0021141649048625794,
#   'label': 0.0021141649048625794,
#   'guitarist': 0.0021141649048625794,
#   'assault': 0.0021141649048625794,
#   'People': 0.0021141649048625794,
#   'bill': 0.0021141649048625794,
#   'documentary': 0.0021141649048625794,
#   'star': 0.004228329809725159,
#   'hammer': 0.0021141649048625794,
#   'production': 0.004228329809725159,
#   'set': 0.0021141649048625794,
#   'crush': 0.0021141649048625794,
#   'musical': 0.0021141649048625794,
#   'theatre': 0.004228329809725159,
#   'hall': 0.0021141649048625794,
#   'director': 0.0021141649048625794,
#   'response': 0.0021141649048625794,
#   'smoke': 0.0021141649048625794,
#   'week': 0.0021141649048625794,
#   'community': 0.0021141649048625794,
#   'changes': 0.0021141649048625794,
#   'incident': 0.0021141649048625794,
#   'galaxy': 0.0021141649048625794,
#   'role': 0.004228329809725159,
#   'Earth': 0.0021141649048625794,
#   'opportunity': 0.0021141649048625794,
#   'forest': 0.0021141649048625794,
#   'author': 0.0021141649048625794,
#   'byline': 0.0021141649048625794,
#   'closet': 0.0021141649048625794,
#   'Beast': 0.0021141649048625794,
#   'street': 0.0021141649048625794,
#   'f-word': 0.0021141649048625794,
#   'results': 0.0021141649048625794,
#   'MC': 0.0021141649048625794,
#   'demographic': 0.0021141649048625794,
#   'craphouse': 0.0021141649048625794,
#   'Parents': 0.004228329809725159,
#   'Friday': 0.0021141649048625794,
#   'Beckhams': 0.0021141649048625794,
#   'Opera': 0.0021141649048625794,
#   'running': 0.0021141649048625794,
#   'moment': 0.0021141649048625794,
#   'mid-1990s': 0.0021141649048625794,
#   'Christ': 0.004228329809725159,
#   'Academy': 0.0021141649048625794,
#   'device': 0.0021141649048625794,
#   'chase': 0.0021141649048625794,
#   'screen': 0.0021141649048625794,
#   'Annies': 0.0021141649048625794,
#   'seats': 0.0021141649048625794,
#   'weekend': 0.0021141649048625794,
#   'lead': 0.004228329809725159,
#   'game': 0.0021141649048625794,
#   'workforce': 0.0021141649048625794,
#   'stairs': 0.0021141649048625794,
#   'same': 0.0021141649048625794,
#   'story': 0.0021141649048625794,
#   'magic': 0.0021141649048625794,
#   'short-term': 0.0021141649048625794,
#   'next': 0.0021141649048625794,
#   'throngs': 0.0021141649048625794,
#   'Baftas': 0.0021141649048625794,
#   'newspaper': 0.0021141649048625794,
#   '1960s': 0.0021141649048625794,
#   'summer': 0.0021141649048625794,
#   'crew': 0.0021141649048625794,
#   'board': 0.0021141649048625794,
#   'writers': 0.0021141649048625794,
#   'limelight': 0.0021141649048625794,
#   'publicity': 0.0021141649048625794,
#   'prize': 0.004228329809725159,
#   'audience': 0.0021141649048625794,
#   'process': 0.0021141649048625794,
#   'boy': 0.0021141649048625794,
#   'jury': 0.0021141649048625794,
#   'Vatican': 0.0021141649048625794,
#   'Pope': 0.0021141649048625794,
#   'museum': 0.0021141649048625794},
#  ('Tate', 'The'): {'.': 0.5, '(': 0.5},
#  ('.', 'messages'): {'The': 1.0},
#  ('The', 'will'): {'messages': 0.02857142857142857,
#   'role': 0.02857142857142857,
#   'winner': 0.02857142857142857,
#   'festival': 0.02857142857142857,
#   'event': 0.05714285714285714,
#   'winners': 0.02857142857142857,
#   'Oscars': 0.02857142857142857,
#   'awards': 0.08571428571428572,
#   'group': 0.02857142857142857,
#   'band': 0.08571428571428572,
#   'cards': 0.02857142857142857,
#   'song': 0.05714285714285714,
#   'Mack': 0.02857142857142857,
#   'story': 0.02857142857142857,
#   'programme': 0.02857142857142857,
#   'celebrities': 0.02857142857142857,
#   'judges': 0.02857142857142857,
#   'show': 0.05714285714285714,
#   'musical': 0.02857142857142857,
#   'concert': 0.02857142857142857,
#   'ceremony': 0.02857142857142857,
#   'music': 0.02857142857142857,
#   'production': 0.02857142857142857,
#   'Pixies': 0.02857142857142857,
#   'train': 0.02857142857142857,
#   'script': 0.02857142857142857,
#   'Aviator': 0.02857142857142857,
#   'film-maker': 0.02857142857142857},
#  ('messages', 'be'): {'will': 1.0},
#  ('will', '``'): {'be': 0.6666666666666666, 'play': 0.3333333333333333},
#  ('be', 'unwrapped'): {'``': 1.0},
#  ('``', "''"): {'unwrapped': 0.008928571428571428,
#   'vast': 0.008928571428571428,
#   'fierce': 0.008928571428571428,
#   'delighted': 0.017857142857142856,
#   'Dirty': 0.008928571428571428,
#   'bump': 0.008928571428571428,
#   'hero': 0.008928571428571428,
#   'barrier-breaking': 0.008928571428571428,
#   'heart-wrenching': 0.008928571428571428,
#   'non-essential': 0.008928571428571428,
#   'Suge': 0.008928571428571428,
#   'untrue': 0.008928571428571428,
#   'LA': 0.008928571428571428,
#   'resting': 0.008928571428571428,
#   'determined': 0.008928571428571428,
#   'sing-along': 0.008928571428571428,
#   'hostility': 0.008928571428571428,
#   'fund': 0.008928571428571428,
#   'invest': 0.008928571428571428,
#   'pollution': 0.008928571428571428,
#   'Nipple-gate': 0.017857142857142856,
#   'sickening': 0.008928571428571428,
#   'supergroup': 0.017857142857142856,
#   'bombarded': 0.008928571428571428,
#   'great': 0.017857142857142856,
#   'unscrupulous': 0.008928571428571428,
#   'lewd': 0.008928571428571428,
#   'offensive': 0.017857142857142856,
#   'pre-masters': 0.017857142857142856,
#   'jostled': 0.008928571428571428,
#   'monumental': 0.017857142857142856,
#   'cool': 0.026785714285714284,
#   'exploits': 0.008928571428571428,
#   'twisted': 0.008928571428571428,
#   'threatening': 0.008928571428571428,
#   'comfortable': 0.008928571428571428,
#   'loopy': 0.008928571428571428,
#   'stressed': 0.008928571428571428,
#   'throne': 0.008928571428571428,
#   'idiotic': 0.017857142857142856,
#   'delight': 0.008928571428571428,
#   'sizable': 0.008928571428571428,
#   'challenge': 0.017857142857142856,
#   'impressive': 0.008928571428571428,
#   'bullying': 0.017857142857142856,
#   'superior': 0.008928571428571428,
#   'agendas': 0.008928571428571428,
#   'hopeful': 0.008928571428571428,
#   'recovering': 0.008928571428571428,
#   'satisfied': 0.008928571428571428,
#   'official': 0.008928571428571428,
#   'haunted': 0.008928571428571428,
#   'horrified': 0.008928571428571428,
#   'devastated': 0.008928571428571428,
#   'detested': 0.008928571428571428,
#   'anti-gay': 0.008928571428571428,
#   'classic': 0.008928571428571428,
#   'Angels': 0.008928571428571428,
#   'butcher': 0.008928571428571428,
#   'black': 0.017857142857142856,
#   'Jazz': 0.017857142857142856,
#   'blues': 0.008928571428571428,
#   'bebop': 0.008928571428571428,
#   'ragtime': 0.008928571428571428,
#   'Urban': 0.017857142857142856,
#   'urban': 0.03571428571428571,
#   'Fathead': 0.008928571428571428,
#   'astounded': 0.008928571428571428,
#   'dead': 0.008928571428571428,
#   'dramatic': 0.008928571428571428,
#   'disadvantaged': 0.008928571428571428,
#   'rugby-tackled': 0.008928571428571428,
#   'jackpot': 0.008928571428571428,
#   'medium': 0.008928571428571428,
#   'thrilled': 0.008928571428571428,
#   'love': 0.008928571428571428,
#   'horrible': 0.008928571428571428,
#   'victim': 0.008928571428571428,
#   'demeaning': 0.008928571428571428,
#   'spark': 0.008928571428571428,
#   'amazing': 0.008928571428571428,
#   'ecstatic': 0.017857142857142856,
#   'fiery': 0.008928571428571428,
#   'snubbing': 0.008928571428571428,
#   'false': 0.008928571428571428,
#   'desperate': 0.008928571428571428,
#   'Jimmy': 0.008928571428571428,
#   'masterpiece': 0.008928571428571428,
#   'retro': 0.008928571428571428,
#   'exciting': 0.008928571428571428,
#   'supersized': 0.008928571428571428,
#   'shield': 0.008928571428571428,
#   'desire': 0.008928571428571428},
#  ('unwrapped', 'by'): {"''": 1.0},
#  ("''", 'sculptor'): {'by': 1.0},
#  ('by', 'Richard'): {'sculptor': 1.0},
#  ('sculptor', 'Wentworth'): {'Richard': 1.0},
#  ('Richard', ','): {'Wentworth': 0.125,
#   'Griffiths': 0.25,
#   'Gere': 0.25,
#   'Fogarty': 0.125,
#   'Diamond': 0.125,
#   'Dreyfuss': 0.125},
#  ('Wentworth', 'who'): {',': 1.0},
#  (',', 'is'): {'who': 0.19318181818181818,
#   'Who': 0.011363636363636364,
#   'and': 0.011363636363636364,
#   'which': 0.42045454545454547,
#   'there': 0.06818181818181818,
#   'it': 0.07954545454545454,
#   'he': 0.056818181818181816,
#   'Davis': 0.011363636363636364,
#   'Foxx': 0.011363636363636364,
#   'this': 0.045454545454545456,
#   'Gervais': 0.011363636363636364,
#   'Angola': 0.011363636363636364,
#   'that': 0.022727272727272728,
#   'northing': 0.011363636363636364,
#   'Bangkok': 0.011363636363636364,
#   'nostalgia': 0.011363636363636364,
#   'she': 0.011363636363636364},
#  ('who', 'responsible'): {'is': 1.0},
#  ('is', 'for'): {'responsible': 0.09090909090909091,
#   'up': 0.24242424242424243,
#   'set': 0.030303030303030304,
#   'nominated': 0.18181818181818182,
#   'preparing': 0.030303030303030304,
#   'known': 0.030303030303030304,
#   'due': 0.09090909090909091,
#   'looking': 0.030303030303030304,
#   'waiting': 0.06060606060606061,
#   'keen': 0.030303030303030304,
#   'renowned': 0.030303030303030304,
#   'calling': 0.030303030303030304,
#   'booked': 0.030303030303030304,
#   'not': 0.030303030303030304,
#   'concern': 0.030303030303030304,
#   'scheduled': 0.030303030303030304},
#  ('responsible', 'decorating'): {'for': 1.0},
#  ('for', 'the'): {'decorating': 0.05263157894736842,
#   'Not': 0.10526315789473684,
#   'by': 0.3684210526315789,
#   'sealing': 0.05263157894736842,
#   'On': 0.05263157894736842,
#   'breaking': 0.05263157894736842,
#   'singing': 0.05263157894736842,
#   '``': 0.05263157894736842,
#   'all': 0.05263157894736842,
#   'staging': 0.05263157894736842,
#   'uncovering': 0.05263157894736842,
#   'paving': 0.05263157894736842},
#  ('decorating', 'tree'): {'the': 1.0},
#  ('the', 'with'): {'tree': 0.02127659574468085,
#   'year': 0.02127659574468085,
#   'fascination': 0.02127659574468085,
#   'field': 0.0425531914893617,
#   'top': 0.0425531914893617,
#   'weekend': 0.06382978723404255,
#   'surprises': 0.02127659574468085,
#   'premiere': 0.02127659574468085,
#   'favourite': 0.0425531914893617,
#   'charts': 0.0425531914893617,
#   'bars': 0.02127659574468085,
#   'case': 0.02127659574468085,
#   'UK': 0.0425531914893617,
#   'show': 0.0851063829787234,
#   'road': 0.0425531914893617,
#   'awards': 0.02127659574468085,
#   'chest': 0.02127659574468085,
#   'programme': 0.02127659574468085,
#   'stall': 0.02127659574468085,
#   'way': 0.02127659574468085,
#   'accuracy': 0.02127659574468085,
#   'arrangements': 0.02127659574468085,
#   'outsider': 0.02127659574468085,
#   'chart': 0.02127659574468085,
#   'water': 0.02127659574468085,
#   'head': 0.0425531914893617,
#   'ceremony': 0.02127659574468085,
#   'group': 0.02127659574468085,
#   'clash': 0.02127659574468085,
#   'role': 0.02127659574468085,
#   'star': 0.02127659574468085,
#   'list': 0.02127659574468085,
#   'world': 0.02127659574468085,
#   'nominations': 0.02127659574468085,
#   'script': 0.02127659574468085},
#  ('tree', 'broken'): {'with': 1.0},
#  ('with', 'plates'): {'broken': 1.0},
#  ('broken', 'and'): {'plates': 1.0},
#  ('plates', 'light'): {'and': 1.0},
#  ('and', 'bulbs'): {'light': 1.0},
#  ('light', '.'): {'bulbs': 1.0},
#  ('bulbs', 'It'): {'.': 1.0},
#  ('.', 'is'): {'It': 0.32,
#   'Wentworth': 0.01,
#   'Bloom': 0.01,
#   'He': 0.14,
#   'One': 0.02,
#   'Miyagishima': 0.01,
#   'Sideways': 0.03,
#   'This': 0.08,
#   'There': 0.07,
#   'She': 0.07,
#   'Moreno': 0.02,
#   'Considine': 0.01,
#   'PBS': 0.01,
#   'Encore': 0.01,
#   'Barley': 0.01,
#   'Adoption': 0.01,
#   'Comeback': 0.01,
#   'Viacom': 0.01,
#   'That': 0.01,
#   'Clark': 0.02,
#   'Farrell': 0.01,
#   'Urban': 0.01,
#   'JK': 0.01,
#   'Filming': 0.02,
#   'Paver': 0.01,
#   'Corbett': 0.01,
#   'Hoffman': 0.01,
#   'Lee': 0.01,
#   'Tarantino': 0.01,
#   'Morrison': 0.01,
#   'Jackson': 0.01},
#  ('It', 'the'): {'is': 0.19230769230769232,
#   'said': 0.038461538461538464,
#   "'s": 0.19230769230769232,
#   'credited': 0.038461538461538464,
#   'tells': 0.038461538461538464,
#   'features': 0.07692307692307693,
#   'topped': 0.11538461538461539,
#   'exploits': 0.038461538461538464,
#   'says': 0.038461538461538464,
#   'led': 0.038461538461538464,
#   'was': 0.07692307692307693,
#   'attributed': 0.038461538461538464,
#   'will': 0.038461538461538464,
#   'becomes': 0.038461538461538464},
#  ('is', '17th'): {'the': 1.0},
#  ('the', 'year'): {'17th': 0.05555555555555555,
#   'second': 0.05555555555555555,
#   'first': 0.05555555555555555,
#   'third': 0.05555555555555555,
#   'previous': 0.1111111111111111,
#   'following': 0.16666666666666666,
#   'same': 0.16666666666666666,
#   'past': 0.1111111111111111,
#   'last': 0.1111111111111111,
#   'financial': 0.05555555555555555,
#   'coming': 0.05555555555555555},
#  ('17th', 'that'): {'year': 1.0},
#  ('year', 'the'): {'that': 0.10526315789473684,
#   'after': 0.05263157894736842,
#   ',': 0.3684210526315789,
#   'was': 0.15789473684210525,
#   'by': 0.05263157894736842,
#   'because': 0.05263157894736842,
#   'in': 0.05263157894736842,
#   'winning': 0.05263157894736842,
#   'its': 0.05263157894736842,
#   'with': 0.05263157894736842},
#  ('that', 'gallery'): {'the': 1.0},
#  ('the', 'has'): {'gallery': 0.030303030303030304,
#   'owner': 0.030303030303030304,
#   'book': 0.09090909090909091,
#   'hell': 0.030303030303030304,
#   'star': 0.030303030303030304,
#   'world': 0.030303030303030304,
#   'film': 0.030303030303030304,
#   'courthouse': 0.030303030303030304,
#   'label': 0.030303030303030304,
#   'government': 0.030303030303030304,
#   'UK': 0.06060606060606061,
#   'magazine': 0.030303030303030304,
#   'family': 0.030303030303030304,
#   'US': 0.030303030303030304,
#   'comedian': 0.030303030303030304,
#   'channel': 0.030303030303030304,
#   'Academy': 0.030303030303030304,
#   'BBC': 0.030303030303030304,
#   'series': 0.030303030303030304,
#   'singer': 0.030303030303030304,
#   'album': 0.030303030303030304,
#   'Pops': 0.030303030303030304,
#   'radio': 0.030303030303030304,
#   'song': 0.030303030303030304,
#   'date': 0.030303030303030304,
#   'show': 0.030303030303030304,
#   'pig': 0.030303030303030304,
#   'festival': 0.06060606060606061,
#   'workforce': 0.030303030303030304},
#  ('gallery', 'invited'): {'has': 1.0},
#  ('has', 'an'): {'invited': 0.09090909090909091,
#   'become': 0.2727272727272727,
#   'received': 0.09090909090909091,
#   'drawn': 0.09090909090909091,
#   'seen': 0.09090909090909091,
#   'meant': 0.09090909090909091,
#   'expressed': 0.09090909090909091,
#   'won': 0.09090909090909091,
#   'had': 0.09090909090909091},
#  ('invited', 'artist'): {'an': 1.0},
#  ('an', 'to'): {'artist': 0.13043478260869565,
#   'assistant': 0.043478260869565216,
#   'opportunity': 0.043478260869565216,
#   'effort': 0.17391304347826086,
#   'attempt': 0.2608695652173913,
#   'alternative': 0.13043478260869565,
#   'edge': 0.043478260869565216,
#   'embarassment': 0.043478260869565216,
#   'idol': 0.043478260869565216,
#   'end': 0.043478260869565216,
#   'hour': 0.043478260869565216},
#  ('artist', 'dress'): {'to': 1.0},
#  ('to', 'their'): {'dress': 0.024390243902439025,
#   'share': 0.024390243902439025,
#   'read': 0.024390243902439025,
#   'trim': 0.04878048780487805,
#   'pay': 0.04878048780487805,
#   'self-censor': 0.024390243902439025,
#   'choose': 0.024390243902439025,
#   'return': 0.024390243902439025,
#   'retain': 0.04878048780487805,
#   'make': 0.024390243902439025,
#   'pursue': 0.024390243902439025,
#   'get': 0.024390243902439025,
#   'score': 0.024390243902439025,
#   'supply': 0.024390243902439025,
#   'mark': 0.04878048780487805,
#   'record': 0.0975609756097561,
#   'turn': 0.024390243902439025,
#   'continue': 0.024390243902439025,
#   'protect': 0.04878048780487805,
#   'call': 0.024390243902439025,
#   'update': 0.024390243902439025,
#   'find': 0.024390243902439025,
#   'relocate': 0.024390243902439025,
#   'host': 0.024390243902439025,
#   'release': 0.024390243902439025,
#   'have': 0.024390243902439025,
#   'ask': 0.024390243902439025,
#   'increase': 0.024390243902439025,
#   'save': 0.024390243902439025,
#   'judge': 0.024390243902439025,
#   'secure': 0.024390243902439025,
#   'meet': 0.024390243902439025,
#   'challenge': 0.024390243902439025},
#  ('dress', 'Christmas'): {'their': 1.0},
#  ('their', 'tree'): {'Christmas': 1.0},
#  ('Christmas', '.'): {'tree': 0.16666666666666666,
#   'Day': 0.5,
#   'market': 0.16666666666666666,
#   'specials': 0.16666666666666666},
#  ('tree', 'Artists'): {'.': 1.0},
#  ('.', 'who'): {'Artists': 0.1,
#   'Customers': 0.1,
#   'Those': 0.2,
#   'Everyone': 0.1,
#   'Anybody': 0.1,
#   'Fans': 0.1,
#   'Anyone': 0.1,
#   'And': 0.2},
#  ('Artists', 'have'): {'who': 1.0},
#  ('who', 'decorated'): {'have': 1.0},
#  ('have', 'the'): {'decorated': 0.03225806451612903,
#   'for': 0.03225806451612903,
#   'banned': 0.03225806451612903,
#   'made': 0.03225806451612903,
#   'given': 0.03225806451612903,
#   'won': 0.0967741935483871,
#   'savaged': 0.03225806451612903,
#   'demanded': 0.03225806451612903,
#   'used': 0.03225806451612903,
#   'said': 0.03225806451612903,
#   'entered': 0.03225806451612903,
#   'in': 0.03225806451612903,
#   'met': 0.03225806451612903,
#   'enabled': 0.06451612903225806,
#   'thought': 0.03225806451612903,
#   'screened': 0.03225806451612903,
#   'urged': 0.03225806451612903,
#   'underestimated': 0.03225806451612903,
#   'seen': 0.03225806451612903,
#   'heard': 0.03225806451612903,
#   'joined': 0.03225806451612903,
#   'broken': 0.03225806451612903,
#   'included': 0.03225806451612903,
#   'shared': 0.03225806451612903,
#   'been': 0.03225806451612903,
#   'hailed': 0.03225806451612903,
#   'explored': 0.03225806451612903,
#   'secured': 0.03225806451612903},
#  ('decorated', 'Tate'): {'the': 1.0},
#  ('the', 'tree'): {'Tate': 1.0},
#  ('Tate', 'in'): {'tree': 1.0},
#  ('tree', 'previous'): {'in': 1.0},
#  ('in', 'years'): {'previous': 0.08695652173913043,
#   'recent': 0.30434782608695654,
#   'three': 0.08695652173913043,
#   'six': 0.043478260869565216,
#   '25': 0.17391304347826086,
#   '20': 0.043478260869565216,
#   'eight': 0.043478260869565216,
#   'subsequent': 0.043478260869565216,
#   'five': 0.08695652173913043,
#   '23': 0.043478260869565216,
#   'four': 0.043478260869565216},
#  ('previous', 'include'): {'years': 1.0},
#  ('years', 'Tracey'): {'include': 1.0},
#  ('include', 'Emin'): {'Tracey': 1.0},
#  ('Tracey', 'in'): {'Emin': 1.0},
#  ('Emin', '2002'): {'in': 1.0},
#  ('in', '.'): {'2002': 0.044,
#   '2003': 0.056,
#   '1968': 0.012,
#   'Ballymena': 0.004,
#   'London': 0.02,
#   '1958': 0.008,
#   '2001': 0.032,
#   '1776': 0.004,
#   '1910': 0.004,
#   'America': 0.004,
#   'lifestyle': 0.004,
#   '1985': 0.012,
#   '1996': 0.016,
#   'Italy': 0.008,
#   '2004': 0.06,
#   '1989': 0.012,
#   'Dominica': 0.004,
#   'movies': 0.004,
#   '2006': 0.008,
#   'Closer': 0.024,
#   'February': 0.028,
#   '1949': 0.004,
#   'Belgium': 0.004,
#   'Kigali': 0.004,
#   'Paris': 0.004,
#   'January': 0.012,
#   'India': 0.012,
#   '1993': 0.016,
#   'Europe': 0.008,
#   'total': 0.012,
#   'two': 0.004,
#   'Ray': 0.008,
#   '1990': 0.004,
#   'film': 0.008,
#   'Hollywood': 0.004,
#   'Deadwood': 0.004,
#   'LA': 0.004,
#   'Iraq': 0.008,
#   'jail': 0.008,
#   'Utah': 0.004,
#   '1981': 0.012,
#   'Chechnya': 0.004,
#   'December': 0.016,
#   'Maryland': 0.004,
#   'Miami': 0.004,
#   '1979': 0.012,
#   '2000': 0.008,
#   'hospital': 0.008,
#   '1959': 0.004,
#   '1980': 0.004,
#   'Fulham': 0.004,
#   'music': 0.008,
#   'June': 0.012,
#   'April': 0.008,
#   'Switzerland': 0.004,
#   'Africa': 0.008,
#   'Florida': 0.012,
#   'Bakersfield': 0.004,
#   'September': 0.012,
#   'August': 0.008,
#   '1999': 0.012,
#   'November': 0.008,
#   '1984': 0.004,
#   'schools': 0.008,
#   'Rome': 0.012,
#   '1991': 0.008,
#   'tune': 0.004,
#   'it': 0.004,
#   'October': 0.02,
#   '1937': 0.008,
#   'production': 0.004,
#   '1962': 0.004,
#   'mid-air': 0.004,
#   'here': 0.004,
#   'Guernsey': 0.004,
#   'EastEnders': 0.004,
#   'society': 0.004,
#   'Wales': 0.008,
#   'general': 0.004,
#   '1978': 0.004,
#   'Wambo': 0.004,
#   'Fingersmith': 0.004,
#   '1957': 0.004,
#   'Birmingham': 0.008,
#   'March': 0.012,
#   'time': 0.004,
#   'China': 0.004,
#   '2005': 0.008,
#   '1998': 0.008,
#   '1987': 0.004,
#   'trouble': 0.004,
#   '1994': 0.008,
#   'common': 0.004,
#   '1965': 0.004,
#   '1982': 0.004,
#   'English': 0.004,
#   'July': 0.008,
#   '1997': 0.004,
#   'White': 0.004,
#   '1938': 0.004,
#   'there': 0.004,
#   'third': 0.008,
#   'England': 0.004,
#   'Canada': 0.004,
#   '1948': 0.004,
#   'May': 0.004,
#   '1952': 0.004,
#   'Glasgow': 0.004,
#   '1934': 0.004,
#   '1939': 0.004,
#   'Chocolat': 0.004,
#   'history': 0.008,
#   'condoms': 0.004,
#   'television': 0.004,
#   'rest': 0.004,
#   'Brussels': 0.004,
#   'public': 0.004,
#   'Alias': 0.004,
#   '2007': 0.004,
#   'prison': 0.004,
#   'France': 0.004,
#   '1969': 0.004,
#   'Germany': 0.004,
#   'Wellington': 0.004},
#  ('The', 'green'): {'plain': 1.0},
#  ('plain', 'Norway'): {'green': 1.0},
#  ('green', 'spruce'): {'Norway': 1.0},
#  ('Norway', 'is'): {'spruce': 1.0},
#  ('spruce', 'displayed'): {'is': 1.0},
#  ('is', 'in'): {'displayed': 0.030303030303030304,
#   'set': 0.15151515151515152,
#   'now': 0.06060606060606061,
#   'auctioned': 0.030303030303030304,
#   'also': 0.030303030303030304,
#   'trapped': 0.030303030303030304,
#   'seen': 0.06060606060606061,
#   'God-like': 0.030303030303030304,
#   'holidaying': 0.030303030303030304,
#   'due': 0.030303030303030304,
#   'already': 0.030303030303030304,
#   'released': 0.06060606060606061,
#   'starring': 0.030303030303030304,
#   '91st': 0.030303030303030304,
#   'pencilled': 0.030303030303030304,
#   'reflected': 0.030303030303030304,
#   'made': 0.030303030303030304,
#   'anyone': 0.030303030303030304,
#   '``': 0.030303030303030304,
#   'currently': 0.06060606060606061,
#   'working': 0.030303030303030304,
#   'held': 0.030303030303030304,
#   'nominated': 0.030303030303030304,
#   'out': 0.030303030303030304,
#   'put': 0.030303030303030304},
#  ('displayed', 'the'): {'in': 1.0},
#  ('in', 'gallery'): {'the': 1.0},
#  ('the', "'s"): {'gallery': 0.010101010101010102,
#   'children': 0.03535353535353535,
#   'nanny': 0.005050505050505051,
#   'musical': 0.010101010101010102,
#   'Cuckoo': 0.010101010101010102,
#   'RSC': 0.005050505050505051,
#   'council': 0.010101010101010102,
#   'work': 0.005050505050505051,
#   'play': 0.010101010101010102,
#   'BBC': 0.05555555555555555,
#   'RCA': 0.005050505050505051,
#   'UK': 0.06060606060606061,
#   'prize': 0.005050505050505051,
#   '1980': 0.005050505050505051,
#   'artist': 0.005050505050505051,
#   'company': 0.020202020202020204,
#   'book': 0.005050505050505051,
#   'country': 0.03535353535353535,
#   'film': 0.06565656565656566,
#   'group': 0.015151515151515152,
#   'festival': 0.03535353535353535,
#   'Hollywood': 0.020202020202020204,
#   'movie': 0.005050505050505051,
#   'DVD': 0.010101010101010102,
#   'nation': 0.010101010101010102,
#   'producer': 0.005050505050505051,
#   'show': 0.06060606060606061,
#   'People': 0.010101010101010102,
#   'industry': 0.005050505050505051,
#   'band': 0.07575757575757576,
#   'year': 0.015151515151515152,
#   'star': 0.005050505050505051,
#   'week': 0.005050505050505051,
#   'woman': 0.010101010101010102,
#   'weather': 0.005050505050505051,
#   'song': 0.005050505050505051,
#   'killer': 0.005050505050505051,
#   'singer': 0.025252525252525252,
#   'University': 0.005050505050505051,
#   'night': 0.020202020202020204,
#   'event': 0.010101010101010102,
#   'city': 0.010101010101010102,
#   'station': 0.015151515151515152,
#   'magazine': 0.010101010101010102,
#   'channel': 0.010101010101010102,
#   'contest': 0.005050505050505051,
#   'network': 0.010101010101010102,
#   'FCC': 0.010101010101010102,
#   'people': 0.010101010101010102,
#   'capital': 0.005050505050505051,
#   'committee': 0.005050505050505051,
#   'programme': 0.020202020202020204,
#   'album': 0.010101010101010102,
#   'school': 0.005050505050505051,
#   'actor': 0.005050505050505051,
#   'DJ': 0.005050505050505051,
#   'venue': 0.005050505050505051,
#   'record': 0.005050505050505051,
#   'tour': 0.005050505050505051,
#   'scene': 0.005050505050505051,
#   'musician': 0.005050505050505051,
#   'radio': 0.005050505050505051,
#   'NME': 0.005050505050505051,
#   'guitarist': 0.005050505050505051,
#   'Billboard': 0.005050505050505051,
#   'director': 0.010101010101010102,
#   'rapper': 0.005050505050505051,
#   '24-year-old': 0.005050505050505051,
#   'world': 0.010101010101010102,
#   'judge': 0.005050505050505051,
#   'story': 0.005050505050505051,
#   'original': 0.010101010101010102,
#   'public': 0.005050505050505051,
#   'Observer': 0.005050505050505051,
#   'Academy': 0.005050505050505051,
#   'accuser': 0.005050505050505051,
#   'boy': 0.005050505050505051,
#   'prosecution': 0.010101010101010102,
#   'Director': 0.005050505050505051},
#  ('gallery', 'foyer'): {"'s": 1.0},
#  ("'s", '.'): {'foyer': 0.010638297872340425,
#   'winner': 0.010638297872340425,
#   'Nest': 0.010638297872340425,
#   'empowerment': 0.010638297872340425,
#   'demise': 0.010638297872340425,
#   'limelight': 0.010638297872340425,
#   'Shoes': 0.010638297872340425,
#   'chief': 0.010638297872340425,
#   'ceremony': 0.010638297872340425,
#   'credit': 0.02127659574468085,
#   'funeral': 0.02127659574468085,
#   'murder': 0.010638297872340425,
#   '12': 0.010638297872340425,
#   'Oscars': 0.05319148936170213,
#   'Cesars': 0.010638297872340425,
#   'mother': 0.010638297872340425,
#   'colder': 0.010638297872340425,
#   'spell': 0.010638297872340425,
#   'regime': 0.010638297872340425,
#   'office': 0.010638297872340425,
#   'Graceland': 0.010638297872340425,
#   'career': 0.010638297872340425,
#   'birth': 0.031914893617021274,
#   'place': 0.02127659574468085,
#   'site': 0.010638297872340425,
#   'recording': 0.010638297872340425,
#   'Closer': 0.010638297872340425,
#   'show': 0.010638297872340425,
#   'part': 0.010638297872340425,
#   'anniversary': 0.010638297872340425,
#   'cave': 0.010638297872340425,
#   'Kitchen': 0.010638297872340425,
#   'perceptions': 0.010638297872340425,
#   'slot': 0.010638297872340425,
#   'action': 0.010638297872340425,
#   'history': 0.010638297872340425,
#   'conference': 0.010638297872340425,
#   'Schooldays': 0.010638297872340425,
#   'producers': 0.02127659574468085,
#   'family': 0.010638297872340425,
#   'death': 0.010638297872340425,
#   'box': 0.02127659574468085,
#   'Christmas': 0.010638297872340425,
#   'departure': 0.010638297872340425,
#   '1,000th': 0.010638297872340425,
#   'artwork': 0.010638297872340425,
#   'event': 0.010638297872340425,
#   "'orrible": 0.010638297872340425,
#   'regressive': 0.010638297872340425,
#   'headquarters': 0.010638297872340425,
#   'reception': 0.010638297872340425,
#   'wrong': 0.010638297872340425,
#   'home': 0.02127659574468085,
#   'songs': 0.010638297872340425,
#   'earpiece': 0.010638297872340425,
#   'entourage': 0.010638297872340425,
#   'release': 0.010638297872340425,
#   'Requiem': 0.010638297872340425,
#   'script': 0.010638297872340425,
#   'teacher': 0.010638297872340425,
#   'characters': 0.010638297872340425,
#   'festival': 0.010638297872340425,
#   'Web': 0.010638297872340425,
#   'novel': 0.010638297872340425,
#   'book': 0.010638297872340425,
#   'skyscrapers': 0.010638297872340425,
#   'covers': 0.010638297872340425,
#   'catastrophe': 0.010638297872340425,
#   'vehicle': 0.010638297872340425,
#   'life': 0.010638297872340425,
#   'work': 0.010638297872340425,
#   'backfiring': 0.010638297872340425,
#   'music': 0.010638297872340425,
#   'programme': 0.010638297872340425,
#   'programs': 0.010638297872340425,
#   'car': 0.010638297872340425,
#   'Inc': 0.010638297872340425,
#   'film': 0.02127659574468085,
#   'imagination': 0.010638297872340425,
#   'mouth': 0.010638297872340425,
#   'incredible': 0.010638297872340425},
#  ('foyer', 'Its'): {'.': 1.0},
#  ('.', 'light'): {'Its': 1.0},
#  ('Its', 'bulb'): {'light': 1.0},
#  ('light', 'adornments'): {'bulb': 1.0},
#  ('bulb', 'are'): {'adornments': 1.0},
#  ('adornments', 'dimmed'): {'are': 1.0},
#  ('are', ','): {'dimmed': 0.09090909090909091,
#   'British': 0.09090909090909091,
#   'confirmed': 0.09090909090909091,
#   'interrupted': 0.09090909090909091,
#   'commentaries': 0.09090909090909091,
#   'formulaic': 0.09090909090909091,
#   'catchy': 0.09090909090909091,
#   'kidding': 0.09090909090909091,
#   'judged': 0.09090909090909091,
#   'down': 0.09090909090909091,
#   'booming': 0.09090909090909091},
#  ('dimmed', 'ordinary'): {',': 1.0},
#  (',', 'domestic'): {'ordinary': 1.0},
#  ('ordinary', 'ones'): {'domestic': 1.0},
#  ('domestic', 'joined'): {'ones': 1.0},
#  ('ones', 'together'): {'joined': 1.0},
#  ('joined', 'with'): {'together': 0.5, 'forces': 0.5},
#  ('together', 'string'): {'with': 1.0},
#  ('with', '.'): {'string': 0.038461538461538464,
#   'fundraising': 0.038461538461538464,
#   '2003': 0.038461538461538464,
#   'Grudge': 0.038461538461538464,
#   'her': 0.07692307692307693,
#   'Howard': 0.038461538461538464,
#   'Day-Lewis': 0.07692307692307693,
#   'marijuana': 0.038461538461538464,
#   'them': 0.038461538461538464,
#   'him': 0.038461538461538464,
#   'Breathe': 0.038461538461538464,
#   'Filthy/Gorgeous': 0.038461538461538464,
#   'depression': 0.038461538461538464,
#   'me': 0.07692307692307693,
#   'us': 0.038461538461538464,
#   'age': 0.038461538461538464,
#   '£5m': 0.038461538461538464,
#   'praise': 0.038461538461538464,
#   'beads': 0.038461538461538464,
#   'Buhecha': 0.038461538461538464,
#   'casualty': 0.038461538461538464,
#   '11': 0.038461538461538464,
#   'Carpenter': 0.038461538461538464},
#  ('string', 'The'): {'.': 1.0},
#  ('.', 'plates'): {'The': 1.0},
#  ('The', 'decorating'): {'plates': 1.0},
#  ('plates', 'the'): {'decorating': 1.0},
#  ('decorating', 'branches'): {'the': 1.0},
#  ('the', 'will'): {'branches': 0.034482758620689655,
#   'sale': 0.06896551724137931,
#   'collection': 0.034482758620689655,
#   'contest': 0.034482758620689655,
#   'episode': 0.034482758620689655,
#   'FCC': 0.034482758620689655,
#   'awards': 0.034482758620689655,
#   'ceremony': 0.034482758620689655,
#   'song': 0.034482758620689655,
#   'show': 0.034482758620689655,
#   'album': 0.034482758620689655,
#   'audience': 0.034482758620689655,
#   'Pops': 0.06896551724137931,
#   '28-year-old': 0.034482758620689655,
#   'film': 0.034482758620689655,
#   'fans': 0.034482758620689655,
#   'band': 0.034482758620689655,
#   'musical': 0.034482758620689655,
#   'unexpected': 0.034482758620689655,
#   'winners': 0.034482758620689655,
#   'Park': 0.034482758620689655,
#   'concert': 0.034482758620689655,
#   'cast': 0.034482758620689655,
#   'stunts': 0.034482758620689655,
#   'years': 0.034482758620689655,
#   'museum': 0.06896551724137931},
#  ('branches', 'be'): {'will': 1.0},
#  ('will', 'auctioned'): {'be': 1.0},
#  ('be', 'off'): {'auctioned': 0.25, 'voted': 0.5, 'sold': 0.25},
#  ('auctioned', 'for'): {'off': 1.0},
#  ('off', 'the'): {'for': 0.5, 'of': 0.5},
#  ('for', 'children'): {'the': 0.5, 'young': 0.5},
#  ('children', 'charity'): {"'s": 1.0},
#  ("'s", 'ArtWorks'): {'charity': 1.0},
#  ('charity', '.'): {'ArtWorks': 0.16666666666666666,
#   'element': 0.16666666666666666,
#   'prize': 0.3333333333333333,
#   'appeal': 0.16666666666666666,
#   'song': 0.16666666666666666},
#  ('ArtWorks', 'Wentworth'): {'.': 1.0},
#  ('.', 'worked'): {'Wentworth': 0.3333333333333333,
#   'Hailey': 0.3333333333333333,
#   'He': 0.3333333333333333},
#  ('Wentworth', 'as'): {'worked': 1.0},
#  ('worked', 'an'): {'as': 1.0},
#  ('as', 'assistant'): {'an': 1.0},
#  ('assistant', 'sculptor'): {'to': 1.0},
#  ('to', 'Henry'): {'sculptor': 1.0},
#  ('sculptor', 'Moore'): {'Henry': 1.0},
#  ('Henry', 'in'): {'Moore': 0.5, 'Fonda': 0.5},
#  ('Moore', 'the'): {'in': 0.5, 'told': 0.5},
#  ('in', 'late'): {'the': 0.75, 'his': 0.25},
#  ('the', '1960s'): {'late': 0.6666666666666666,
#   'original': 0.3333333333333333},
#  ('late', '.'): {'1960s': 0.3333333333333333,
#   'father': 0.3333333333333333,
#   '2007': 0.3333333333333333},
#  ('1960s', 'His'): {'.': 1.0},
#  ('.', 'reputation'): {'His': 1.0},
#  ('His', 'as'): {'reputation': 1.0},
#  ('reputation', 'a'): {'as': 1.0},
#  ('as', 'sculptor'): {'a': 1.0},
#  ('a', 'grew'): {'sculptor': 1.0},
#  ('sculptor', 'in'): {'grew': 1.0},
#  ('grew', 'the'): {'in': 1.0},
#  ('in', '1980s'): {'the': 1.0},
#  ('the', ','): {'1980s': 0.02577319587628866,
#   'stage': 0.010309278350515464,
#   'genre': 0.002577319587628866,
#   'book': 0.01288659793814433,
#   'capital': 0.005154639175257732,
#   'world': 0.020618556701030927,
#   'hypocrisy': 0.002577319587628866,
#   'theatre': 0.005154639175257732,
#   'mid-70s': 0.002577319587628866,
#   'form': 0.002577319587628866,
#   'sky': 0.002577319587628866,
#   'Bahamas': 0.002577319587628866,
#   'show': 0.023195876288659795,
#   'country': 0.010309278350515464,
#   'RAD': 0.002577319587628866,
#   'piano': 0.005154639175257732,
#   'UK': 0.01804123711340206,
#   'US': 0.07216494845360824,
#   'better': 0.002577319587628866,
#   'screenplay': 0.002577319587628866,
#   'invasion': 0.002577319587628866,
#   'figures': 0.002577319587628866,
#   'merrier': 0.002577319587628866,
#   'warm': 0.002577319587628866,
#   'year': 0.028350515463917526,
#   'Dead': 0.005154639175257732,
#   'square': 0.002577319587628866,
#   'star': 0.002577319587628866,
#   'story': 0.007731958762886598,
#   'film': 0.041237113402061855,
#   'idea': 0.005154639175257732,
#   'streets': 0.002577319587628866,
#   'running': 0.002577319587628866,
#   'festival': 0.010309278350515464,
#   'World': 0.007731958762886598,
#   'lawsuit': 0.005154639175257732,
#   'murders': 0.002577319587628866,
#   'Phoenix': 0.005154639175257732,
#   'part': 0.010309278350515464,
#   'fleshiness': 0.002577319587628866,
#   'shortlist': 0.002577319587628866,
#   'event': 0.002577319587628866,
#   'stops': 0.002577319587628866,
#   'market': 0.002577319587628866,
#   'ceremony': 0.015463917525773196,
#   'novel': 0.005154639175257732,
#   'poll': 0.002577319587628866,
#   'Sea': 0.005154639175257732,
#   'Knife': 0.002577319587628866,
#   '1950s': 0.002577319587628866,
#   'results': 0.002577319587628866,
#   'Kranks': 0.002577319587628866,
#   'weekend': 0.007731958762886598,
#   'winners': 0.002577319587628866,
#   '1940s': 0.002577319587628866,
#   'films': 0.002577319587628866,
#   'Church': 0.002577319587628866,
#   'Authority': 0.002577319587628866,
#   'individual': 0.002577319587628866,
#   'piece': 0.002577319587628866,
#   'Oscars': 0.005154639175257732,
#   'elite': 0.002577319587628866,
#   'follow-up': 0.005154639175257732,
#   'trial': 0.005154639175257732,
#   'years': 0.002577319587628866,
#   'recording': 0.002577319587628866,
#   'studio': 0.007731958762886598,
#   'past': 0.007731958762886598,
#   'obvious': 0.002577319587628866,
#   'greatest': 0.002577319587628866,
#   'project': 0.005154639175257732,
#   'album': 0.002577319587628866,
#   'carnival': 0.002577319587628866,
#   'Maracana': 0.002577319587628866,
#   'road': 0.005154639175257732,
#   'video': 0.002577319587628866,
#   'Byrds': 0.007731958762886598,
#   'mid-1960s': 0.002577319587628866,
#   'rumours': 0.002577319587628866,
#   'public': 0.005154639175257732,
#   'list': 0.010309278350515464,
#   'Brits': 0.002577319587628866,
#   'earth': 0.002577319587628866,
#   'band': 0.01804123711340206,
#   'anger': 0.002577319587628866,
#   'title': 0.002577319587628866,
#   '8,000': 0.002577319587628866,
#   'system': 0.002577319587628866,
#   'venue': 0.002577319587628866,
#   'police': 0.002577319587628866,
#   'house': 0.007731958762886598,
#   'survey': 0.005154639175257732,
#   'Atlantic': 0.007731958762886598,
#   'single': 0.007731958762886598,
#   'sample': 0.002577319587628866,
#   'scheme': 0.002577319587628866,
#   'killing': 0.002577319587628866,
#   'Beatles': 0.002577319587628866,
#   'awards': 0.005154639175257732,
#   'money': 0.002577319587628866,
#   'music': 0.005154639175257732,
#   'fight': 0.005154639175257732,
#   'time': 0.010309278350515464,
#   'order': 0.002577319587628866,
#   'auction': 0.002577319587628866,
#   'line-up': 0.002577319587628866,
#   'body': 0.002577319587628866,
#   'series': 0.005154639175257732,
#   'Beautiful': 0.002577319587628866,
#   'air': 0.002577319587628866,
#   'sale': 0.005154639175257732,
#   'pieces': 0.002577319587628866,
#   'walls': 0.002577319587628866,
#   'lock-up': 0.002577319587628866,
#   'advert': 0.002577319587628866,
#   'programme': 0.007731958762886598,
#   'contest': 0.002577319587628866,
#   'mid-1990s': 0.002577319587628866,
#   'globe': 0.002577319587628866,
#   'dancefloor': 0.002577319587628866,
#   'BBC': 0.002577319587628866,
#   'programmes': 0.002577319587628866,
#   'roof': 0.002577319587628866,
#   'case': 0.007731958762886598,
#   'courtroom': 0.002577319587628866,
#   'resources': 0.002577319587628866,
#   'same': 0.005154639175257732,
#   'marvellous': 0.002577319587628866,
#   'playground': 0.002577319587628866,
#   'claim': 0.002577319587628866,
#   'audience': 0.010309278350515464,
#   'missing': 0.002577319587628866,
#   'villages': 0.002577319587628866,
#   'bush': 0.002577319587628866,
#   'industry': 0.007731958762886598,
#   'cleaners': 0.002577319587628866,
#   'final': 0.002577319587628866,
#   'Navy': 0.002577319587628866,
#   'plane': 0.002577319587628866,
#   'mid-week': 0.002577319587628866,
#   'score': 0.002577319587628866,
#   'day': 0.002577319587628866,
#   'tour': 0.002577319587628866,
#   'song': 0.002577319587628866,
#   'upside': 0.002577319587628866,
#   'scene': 0.002577319587628866,
#   'Park': 0.002577319587628866,
#   'Streets': 0.002577319587628866,
#   'labels': 0.002577319587628866,
#   'building': 0.002577319587628866,
#   'second': 0.002577319587628866,
#   'Wire': 0.002577319587628866,
#   'top': 0.002577319587628866,
#   'radio': 0.002577319587628866,
#   'start': 0.002577319587628866,
#   'four': 0.002577319587628866,
#   'Gielgud': 0.002577319587628866,
#   'Libertines': 0.002577319587628866,
#   'front': 0.002577319587628866,
#   'curfew': 0.002577319587628866,
#   'Volksoper': 0.002577319587628866,
#   'name': 0.002577319587628866,
#   'sun': 0.002577319587628866,
#   'scenes': 0.002577319587628866,
#   'orchestra': 0.002577319587628866,
#   'technology': 0.002577319587628866,
#   'charts': 0.002577319587628866,
#   'Pretenders': 0.005154639175257732,
#   "O'Jays": 0.002577319587628866,
#   'singer': 0.002577319587628866,
#   'gig': 0.002577319587628866,
#   'cast': 0.007731958762886598,
#   'musical': 0.002577319587628866,
#   'production': 0.002577319587628866,
#   'Whale': 0.002577319587628866,
#   'pig': 0.002577319587628866,
#   'sidekick': 0.002577319587628866,
#   'internet': 0.002577319587628866,
#   'West': 0.002577319587628866,
#   'chart': 0.007731958762886598,
#   'House': 0.002577319587628866,
#   'war': 0.002577319587628866,
#   'Academy': 0.005154639175257732,
#   'Fockers': 0.010309278350515464,
#   'movies': 0.002577319587628866,
#   'Caribbean': 0.002577319587628866,
#   'new': 0.002577319587628866,
#   'Friday': 0.002577319587628866,
#   'Rings': 0.005154639175257732,
#   'train': 0.002577319587628866,
#   'camera': 0.002577319587628866,
#   'Baftas': 0.005154639175257732,
#   'cards': 0.002577319587628866,
#   'Wheelies': 0.002577319587628866,
#   'Builder': 0.002577319587628866,
#   'city': 0.005154639175257732,
#   'Christ': 0.005154639175257732,
#   'movie': 0.002577319587628866,
#   'Mask': 0.002577319587628866,
#   'bag': 0.002577319587628866,
#   'category': 0.002577319587628866,
#   'breadline': 0.005154639175257732,
#   'fuss': 0.002577319587628866,
#   'future': 0.002577319587628866,
#   'night': 0.002577319587628866,
#   'broadcast': 0.002577319587628866,
#   'prosecution': 0.002577319587628866,
#   'ranks': 0.002577319587628866,
#   '1960s': 0.002577319587628866,
#   'devil': 0.002577319587628866},
#  ('1980s', 'while'): {',': 1.0},
#  (',', 'he'): {'while': 0.005128205128205128,
#   "''": 0.7282051282051282,
#   'where': 0.046153846153846156,
#   'when': 0.015384615384615385,
#   'said': 0.041025641025641026,
#   'and': 0.041025641025641026,
#   'which': 0.035897435897435895,
#   'claiming': 0.015384615384615385,
#   'though': 0.015384615384615385,
#   'because': 0.015384615384615385,
#   'but': 0.010256410256410256,
#   'saying': 0.005128205128205128,
#   'alleging': 0.005128205128205128,
#   'who': 0.005128205128205128,
#   'suggested': 0.005128205128205128,
#   'as': 0.005128205128205128,
#   'whom': 0.005128205128205128},
#  ('while', 'has'): {'he': 0.25,
#   'Sideways': 0.25,
#   'Osbourne': 0.25,
#   'it': 0.25},
#  ('he', 'been'): {'has': 0.4, "'s": 0.2, 'had': 0.4},
# ...
#   'show': 0.018867924528301886,
#   'dollar': 0.018867924528301886,
#   'driving': 0.018867924528301886,
#   'workforce': 0.018867924528301886,
#   'past': 0.018867924528301886,
#   'reference': 0.018867924528301886},
#  ('choice', 'even'): {'is': 1.0},
#  ('is', 'wider'): {'even': 1.0},
#  ('even', 'than'): {'wider': 1.0},
#  ('wider', 'last'): {'than': 1.0},
#  ('than', 'time'): {'last': 1.0},
#  ('last', ','): {'time': 0.05263157894736842,
#   'year': 0.5789473684210527,
#   'Thursday': 0.02631578947368421,
#   'week': 0.05263157894736842,
#   'September': 0.07894736842105263,
#   'album': 0.07894736842105263,
#   'January': 0.02631578947368421,
#   'October': 0.02631578947368421,
#   'single': 0.02631578947368421,
#   'month': 0.05263157894736842},
#  ('time', "''"): {',': 0.5333333333333333, '.': 0.4666666666666667},
#  ("''", 'Madeley'): {'said': 1.0},
#  ('Madeley', '``'): {'.': 1.0},
#  ('.', 'It'): {'``': 0.9701492537313433, "''": 0.029850746268656716},
#  ('``', 'was'): {'It': 0.24242424242424243,
#   'Belfast': 0.030303030303030304,
#   'There': 0.030303030303030304,
#   'Ossie': 0.12121212121212122,
#   'Bob': 0.06060606060606061,
#   'I': 0.18181818181818182,
#   'He': 0.15151515151515152,
#   'Anna': 0.030303030303030304,
#   'This': 0.030303030303030304,
#   'She': 0.09090909090909091,
#   'Hollywood': 0.030303030303030304},
#  ('It', 'very'): {'was': 0.25, "'s": 0.75},
#  ('was', 'hard'): {'very': 1.0},
#  ('very', 'to'): {'hard': 0.6, 'excited': 0.2, 'fortunate': 0.2},
#  ('hard', 'follow'): {'to': 1.0},
#  ('to', 'last'): {'follow': 0.5, '81': 0.5},
#  ('follow', 'year'): {'last': 1.0},
#  ('last', "'s"): {'year': 0.6666666666666666,
#   'week': 0.19047619047619047,
#   'month': 0.047619047619047616,
#   'Sunday': 0.047619047619047616,
#   'weekend': 0.047619047619047616},
#  ('year', 'extremely'): {"'s": 1.0},
#  ("'s", 'successful'): {'extremely': 0.5, 'most': 0.5},
#  ('extremely', 'list'): {'successful': 1.0},
#  ('successful', ','): {'list': 0.5, 'year': 0.5},
#  ('list', 'but'): {',': 1.0},
#  (',', 'we'): {'but': 0.2608695652173913,
#   'what': 0.043478260869565216,
#   'as': 0.08695652173913043,
#   'and': 0.30434782608695654,
#   'because': 0.043478260869565216,
#   'so': 0.17391304347826086,
#   'then': 0.043478260869565216,
#   'would': 0.043478260869565216},
#  ('but', 'think'): {'we': 0.5, 'many': 0.5},
#  ('we', 'this'): {'think': 1.0},
#  ('think', 'year'): {'this': 1.0},
#  ('year', 'books'): {"'s": 1.0},
#  ("'s", 'will'): {'books': 0.1,
#   ',': 0.1,
#   'coverage': 0.1,
#   'bags': 0.1,
#   'festival': 0.2,
#   'chart': 0.1,
#   'show': 0.1,
#   'awards': 0.1,
#   'comedy': 0.1},
#  ('books', 'do'): {'will': 1.0},
#  ('will', 'even'): {'do': 0.5, 'be': 0.5},
#  ('do', 'better'): {'even': 1.0},
#  ('even', ','): {'better': 1.0},
#  ('better', "''"): {',': 1.0},
#  ("''", 'Richard'): {'said': 0.5, 'Co-star': 0.5},
#  ('said', 'and'): {'Richard': 0.25, 'Stiller': 0.25, 'he': 0.25, 'it': 0.25},
#  ('and', 'executive'): {'Judy': 0.3333333333333333,
#   'chief': 0.6666666666666666},
#  ('Judy', 'producer'): {'executive': 1.0},
#  ('executive', 'Amanda'): {'producer': 1.0},
#  ('producer', 'Ross'): {'Amanda': 1.0},
#  ('Amanda', '.'): {'Ross': 0.5, 'Wingfield': 0.5},
#  ('Ross', '``'): {'.': 1.0},
#  ('.', 'We'): {'``': 0.9866666666666667, 'Why': 0.013333333333333334},
#  ('``', 'were'): {'We': 0.7777777777777778,
#   'They': 0.1111111111111111,
#   'Studios': 0.1111111111111111},
#  ('We', 'spoiled'): {'were': 1.0},
#  ('were', 'for'): {'spoiled': 0.07692307692307693,
#   'voted': 0.07692307692307693,
#   'married': 0.07692307692307693,
#   'nominated': 0.3076923076923077,
#   'asked': 0.15384615384615385,
#   'not': 0.07692307692307693,
#   'chosen': 0.07692307692307693,
#   'calls': 0.07692307692307693,
#   'made': 0.07692307692307693},
#  ('spoiled', 'choice'): {'for': 1.0},
#  ('for', 'and'): {'choice': 0.041666666666666664,
#   'Cruel': 0.041666666666666664,
#   'Jesus': 0.041666666666666664,
#   'stage': 0.041666666666666664,
#   "L'Equipier": 0.041666666666666664,
#   'dramas': 0.041666666666666664,
#   'musicals': 0.041666666666666664,
#   'me': 0.041666666666666664,
#   'Ant': 0.041666666666666664,
#   'writing': 0.041666666666666664,
#   'obscene': 0.041666666666666664,
#   'itself': 0.041666666666666664,
#   'assault': 0.041666666666666664,
#   'artist': 0.041666666666666664,
#   'Confessions': 0.041666666666666664,
#   '2004': 0.041666666666666664,
#   'myself': 0.041666666666666664,
#   'Secrets': 0.08333333333333333,
#   'DiCaprio': 0.041666666666666664,
#   'soprano': 0.041666666666666664,
#   'Edward': 0.041666666666666664,
#   'Ray': 0.041666666666666664,
#   'Kinsey': 0.041666666666666664},
#  ('choice', 'it'): {'and': 1.0},
#  ('and', 'was'): {'it': 0.2222222222222222,
#   'preacher': 0.05555555555555555,
#   'Moore': 0.05555555555555555,
#   'she': 0.16666666666666666,
#   'there': 0.16666666666666666,
#   'so': 0.05555555555555555,
#   'he': 0.16666666666666666,
#   'I': 0.05555555555555555,
#   'Demons': 0.05555555555555555},
#  ('it', 'tough'): {'was': 1.0},
#  ('was', 'getting'): {'tough': 0.3333333333333333,
#   'not': 0.3333333333333333,
#   "n't": 0.3333333333333333},
#  ('tough', 'down'): {'getting': 1.0},
#  ('getting', 'to'): {'down': 0.5, 'ready': 0.5},
#  ('down', 'only'): {'to': 1.0},
#  ('to', '10'): {'only': 1.0},
#  ('only', 'from'): {'10': 1.0},
#  ('10', 'the'): {'from': 0.5, 'in': 0.5},
#  ('from', '301'): {'the': 1.0},
#  ('the', 'submitted'): {'301': 1.0},
#  ('301', '.'): {'submitted': 1.0},
#  ('submitted', "''"): {'.': 1.0},
#  ('Poppins', 'gets'): {'musical': 1.0},
#  ('musical', 'flying'): {'gets': 1.0},
#  ('gets', 'start'): {'flying': 1.0},
#  ('The', 'adaptation'): {'stage': 0.5, 'film': 0.5},
#  ('stage', 'of'): {'adaptation': 0.2,
#   'adaptations': 0.2,
#   'production': 0.2,
#   'version': 0.4},
#  ('adaptation', 'children'): {'of': 1.0},
#  ('children', 'film'): {"'s": 1.0},
#  ("'s", 'Mary'): {'film': 1.0},
#  ('film', 'Poppins'): {'Mary': 1.0},
#  ('Mary', 'has'): {'Poppins': 1.0},
#  ('Poppins', 'had'): {'has': 1.0},
#  ('has', 'its'): {'had': 0.16666666666666666,
#   'spawned': 0.16666666666666666,
#   'surpassed': 0.3333333333333333,
#   'taken': 0.16666666666666666,
#   'cancelled': 0.16666666666666666},
#  ('had', 'opening'): {'its': 1.0},
#  ('its', 'night'): {'opening': 1.0},
#  ('opening', 'in'): {'night': 1.0},
#  ('night', 'London'): {'in': 1.0},
#  ('London', 'West'): {"'s": 1.0},
#  ("'s", 'End'): {'West': 1.0},
#  ('West', '.'): {'End': 1.0},
#  ('Sir', 'Mackintosh'): {'Cameron': 1.0},
#  ('Cameron', "'s"): {'Mackintosh': 1.0},
#  ('Mackintosh', 'lavish'): {"'s": 1.0},
#  ("'s", 'production'): {'lavish': 0.5, 'own': 0.5},
#  ('lavish', ','): {'production': 0.5, 'ceremony': 0.5},
#  ('production', 'which'): {',': 1.0},
#  (',', 'has'): {'which': 0.24242424242424243,
#   'who': 0.3484848484848485,
#   'Swank': 0.030303030303030304,
#   'he': 0.030303030303030304,
#   'it': 0.07575757575757576,
#   'but': 0.06060606060606061,
#   'EastEnders': 0.015151515151515152,
#   'and': 0.07575757575757576,
#   'research': 0.015151515151515152,
#   'there': 0.045454545454545456,
#   'Charlie': 0.015151515151515152,
#   'Hoffmann': 0.015151515151515152,
#   'Britain': 0.015151515151515152,
#   'Arnold': 0.015151515151515152},
#  ('which', 'cost'): {'has': 0.5, 'reportedly': 0.5},
#  ('has', '£9m'): {'cost': 1.0},
#  ('cost', 'to'): {'£9m': 1.0},
#  ('£9m', 'bring'): {'to': 1.0},
#  ('to', 'to'): {'bring': 0.04878048780487805,
#   'how': 0.024390243902439025,
#   'campaign': 0.024390243902439025,
#   'Yeats': 0.024390243902439025,
#   'listen': 0.04878048780487805,
#   'want': 0.07317073170731707,
#   'add': 0.04878048780487805,
#   'Willis': 0.024390243902439025,
#   'go': 0.07317073170731707,
#   'do': 0.024390243902439025,
#   'refer': 0.04878048780487805,
#   'travel': 0.04878048780487805,
#   'return': 0.07317073170731707,
#   'commit': 0.024390243902439025,
#   'send': 0.024390243902439025,
#   'appeal': 0.024390243902439025,
#   'offer': 0.024390243902439025,
#   'say': 0.024390243902439025,
#   'respond': 0.07317073170731707,
#   'refuse': 0.024390243902439025,
#   'attach': 0.024390243902439025,
#   'pay': 0.024390243902439025,
#   'fans': 0.024390243902439025,
#   'London': 0.024390243902439025,
#   'fight': 0.024390243902439025,
#   'come': 0.024390243902439025,
#   'April': 0.024390243902439025,
#   'try': 0.024390243902439025},
#  ('bring', 'the'): {'to': 0.5, 'in': 0.25, 'up': 0.25},
#  ('to', 'stage'): {'the': 0.8181818181818182, 'centre': 0.18181818181818182},
#  ('stage', 'was'): {',': 0.6666666666666666, 'act': 0.3333333333333333},
#  (',', 'given'): {'was': 0.3333333333333333, 'are': 0.6666666666666666},
#  ('given', '10-minute'): {'a': 1.0},
#  ('a', 'standing'): {'10-minute': 1.0},
#  ('10-minute', 'ovation'): {'standing': 1.0},
#  ('standing', '.'): {'ovation': 1.0},
#  ('ovation', 'Lead'): {'.': 1.0},
#  ('.', 'actress'): {'Lead': 0.125,
#   'British': 0.25,
#   'Chinese': 0.25,
#   'UK': 0.25,
#   'The': 0.125},
#  ('Lead', 'Laura'): {'actress': 1.0},
#  ('actress', 'Michelle'): {'Laura': 1.0},
#  ('Laura', 'Kelly'): {'Michelle': 1.0},
#  ('Michelle', 'soared'): {'Kelly': 1.0},
#  ('Kelly', 'over'): {'soared': 1.0},
#  ('soared', 'the'): {'over': 0.3333333333333333,
#   'to': 0.3333333333333333,
#   'past': 0.3333333333333333},
#  ('over', 'heads'): {'the': 1.0},
#  ('heads', 'the'): {'of': 1.0},
#  ('of', 'audience'): {'the': 1.0},
#  ('the', 'holding'): {'audience': 1.0},
#  ('audience', 'the'): {'holding': 0.2, 'at': 0.4, 'in': 0.2, 'for': 0.2},
#  ('holding', 'nanny'): {'the': 1.0},
#  ('nanny', 'trademark'): {"'s": 1.0},
#  ("'s", 'umbrella'): {'trademark': 1.0},
#  ('trademark', '.'): {'umbrella': 1.0},
#  ('umbrella', 'Technical'): {'.': 1.0},
#  ('.', 'hitches'): {'Technical': 1.0},
#  ('Technical', 'had'): {'hitches': 1.0},
#  ('hitches', 'prevented'): {'had': 1.0},
#  ('had', 'Mary'): {'prevented': 1.0},
#  ('prevented', 'Poppins'): {'Mary': 1.0},
#  ('Mary', "'"): {'Poppins': 1.0},
#  ('Poppins', 'flight'): {"'": 1.0},
#  ("'", 'into'): {'flight': 1.0},
#  ('flight', 'the'): {'into': 1.0},
#  ('into', 'auditorium'): {'the': 1.0},
#  ('the', 'during'): {'auditorium': 0.2,
#   'industry': 0.2,
#   'piano': 0.2,
#   'singer': 0.2,
#   'UK': 0.2},
#  ('auditorium', 'preview'): {'during': 1.0},
#  ('during', 'performances'): {'preview': 1.0},
#  ('preview', '.'): {'performances': 1.0},
#  ('performances', 'A'): {'.': 1.0},
#  ('.', 'number'): {'A': 0.2, 'The': 0.4, 'At': 0.4},
#  ('number', 'celebrities'): {'of': 1.0},
#  ('of', 'turned'): {'celebrities': 1.0},
#  ('celebrities', 'out'): {'turned': 1.0},
#  ('turned', 'for'): {'out': 1.0},
#  ('out', 'the'): {'for': 0.07894736842105263,
#   'of': 0.3157894736842105,
#   'in': 0.21052631578947367,
#   'all': 0.05263157894736842,
#   'on': 0.13157894736842105,
#   'among': 0.02631578947368421,
#   'across': 0.02631578947368421,
#   'and': 0.02631578947368421,
#   'by': 0.05263157894736842,
#   'at': 0.05263157894736842,
#   'At': 0.02631578947368421},
#  ('for', 'musical'): {'the': 0.2857142857142857,
#   'best': 0.2857142857142857,
#   'a': 0.2857142857142857,
#   'Rings': 0.14285714285714285},
#  ('musical', 'premiere'): {"'s": 1.0},
#  ('premiere', 'including'): {',': 1.0},
#  (',', 'actress'): {'including': 0.75, 'but': 0.25},
#  ('including', 'Barbara'): {'actress': 1.0},
#  ('actress', 'Windsor'): {'Barbara': 1.0},
#  ('Barbara', ','): {'Windsor': 1.0},
#  ('Windsor', 'comic'): {',': 1.0},
#  (',', 'Graham'): {'comic': 1.0},
#  ('comic', 'Norton'): {'Graham': 1.0},
#  ('Graham', 'and'): {'Norton': 1.0},
#  ('Norton', 'Sir'): {'and': 1.0},
#  ('and', 'Richard'): {'Sir': 1.0},
#  ('Sir', 'Attenborough'): {'Richard': 1.0},
#  ('Richard', '.'): {'Attenborough': 0.5, 'III': 0.5},
#  ('show', 'director'): {"'s": 1.0},
#  ("'s", 'Richard'): {'director': 0.5, ',': 0.5},
#  ('director', 'Eyre'): {'Richard': 1.0},
#  ('Richard', 'issued'): {'Eyre': 1.0},
#  ('Eyre', 'a'): {'issued': 1.0},
#  ('issued', 'warning'): {'a': 1.0},
#  ('a', 'earlier'): {'warning': 1.0},
#  ('warning', 'in'): {'earlier': 1.0},
#  ('earlier', 'the'): {'in': 1.0},
#  ('in', 'week'): {'the': 1.0},
#  ('the', 'that'): {'week': 0.03278688524590164,
#   'impression': 0.01639344262295082,
#   'people': 0.01639344262295082,
#   'fact': 0.16393442622950818,
#   'few': 0.01639344262295082,
#   'choices': 0.03278688524590164,
#   'battles': 0.03278688524590164,
#   'magazine': 0.01639344262295082,
#   'system': 0.01639344262295082,
#   'luminosity': 0.01639344262295082,
#   'films': 0.03278688524590164,
#   'hope': 0.03278688524590164,
#   'year': 0.01639344262295082,
#   'stereotypes': 0.01639344262295082,
#   'chemistry': 0.03278688524590164,
#   'track': 0.01639344262295082,
#   'shot': 0.01639344262295082,
#   'two': 0.01639344262295082,
#   'news': 0.01639344262295082,
#   'eccentricity': 0.01639344262295082,
#   'dysfunctions': 0.01639344262295082,
#   'episodes': 0.01639344262295082,
#   'tunes': 0.01639344262295082,
#   'room': 0.01639344262295082,
#   'way': 0.03278688524590164,
#   'talent': 0.01639344262295082,
#   'point': 0.01639344262295082,
#   'soul': 0.01639344262295082,
#   'tributes': 0.01639344262295082,
#   'proposition': 0.01639344262295082,
#   'acts': 0.01639344262295082,
#   'Park': 0.01639344262295082,
#   'viewers': 0.01639344262295082,
#   'things': 0.01639344262295082,
#   'show': 0.01639344262295082,
#   'stage': 0.01639344262295082,
#   'competition': 0.01639344262295082,
#   'depression': 0.01639344262295082,
#   'prospect': 0.01639344262295082,
#   'film': 0.01639344262295082,
#   'children': 0.01639344262295082,
#   'court': 0.03278688524590164,
#   '70s': 0.01639344262295082,
#   'links': 0.01639344262295082},
#  ('week', 'the'): {'that': 0.16666666666666666,
#   'in': 0.16666666666666666,
#   'of': 0.16666666666666666,
#   '-': 0.16666666666666666,
#   'as': 0.16666666666666666,
#   ',': 0.16666666666666666},
#  ('that', 'show'): {'the': 1.0},
#  ('the', 'was'): {'show': 0.016129032258064516,
#   'idea': 0.016129032258064516,
#   'Phoenix': 0.016129032258064516,
#   'title': 0.016129032258064516,
#   'service': 0.03225806451612903,
#   'film': 0.11290322580645161,
#   'injury': 0.016129032258064516,
#   'past': 0.016129032258064516,
#   'King': 0.016129032258064516,
#   'car': 0.016129032258064516,
#   'charts': 0.016129032258064516,
#   'woman': 0.016129032258064516,
#   'band': 0.016129032258064516,
#   'result': 0.016129032258064516,
#   'project': 0.016129032258064516,
#   'school': 0.016129032258064516,
#   'song': 0.03225806451612903,
#   'Government': 0.016129032258064516,
#   'burglar': 0.016129032258064516,
#   'officers': 0.016129032258064516,
#   'album': 0.016129032258064516,
#   'list': 0.03225806451612903,
#   'auction': 0.016129032258064516,
#   'recipient': 0.016129032258064516,
#   'pieces': 0.016129032258064516,
#   'Pops': 0.03225806451612903,
#   'musical': 0.016129032258064516,
#   'station': 0.016129032258064516,
#   'series': 0.016129032258064516,
#   'comedian': 0.016129032258064516,
#   'government': 0.016129032258064516,
#   'line-up': 0.03225806451612903,
#   'record': 0.016129032258064516,
#   'pressure': 0.016129032258064516,
#   'Wire': 0.016129032258064516,
#   'situation': 0.016129032258064516,
#   'video': 0.016129032258064516,
#   'newcomer': 0.016129032258064516,
#   'interview': 0.016129032258064516,
#   'rapper': 0.016129032258064516,
#   'SECC': 0.016129032258064516,
#   'ceremony': 0.016129032258064516,
#   'drop': 0.016129032258064516,
#   'teenager': 0.016129032258064516,
#   'hero': 0.016129032258064516,
#   'Nog': 0.016129032258064516,
#   'night': 0.016129032258064516,
#   'move': 0.016129032258064516,
#   'leaflet': 0.016129032258064516,
#   'year': 0.016129032258064516,
#   'case': 0.016129032258064516},
#  ('show', 'unsuitable'): {'was': 1.0},
#  ('was', 'for'): {'unsuitable': 0.02857142857142857,
#   'known': 0.05714285714285714,
#   'given': 0.02857142857142857,
#   'unavailable': 0.02857142857142857,
#   'hailed': 0.02857142857142857,
#   'nominated': 0.22857142857142856,
#   ',': 0.02857142857142857,
#   'arrested': 0.02857142857142857,
#   'undergoing': 0.02857142857142857,
#   'voted': 0.08571428571428572,
#   'due': 0.02857142857142857,
#   'appropriate': 0.02857142857142857,
#   'need': 0.02857142857142857,
#   'ripe': 0.02857142857142857,
#   'shortlisted': 0.02857142857142857,
#   'sold': 0.02857142857142857,
#   'time': 0.02857142857142857,
#   'best': 0.02857142857142857,
#   'honoured': 0.02857142857142857,
#   'guilty': 0.02857142857142857,
#   'missing': 0.02857142857142857,
#   'true': 0.02857142857142857,
#   'reserved': 0.02857142857142857,
#   'called': 0.02857142857142857,
#   'notorious': 0.02857142857142857},
#  ...}

# %%
texts.iloc[0].split("\n")
# Out:
# ['Gallery unveils interactive tree',
#  '',
#  "A Christmas tree that can receive text messages has been unveiled at London's Tate Britain art gallery.",
#  '',
#  'The spruce has an antenna which can receive Bluetooth texts sent by visitors to the Tate. The messages will be "unwrapped" by sculptor Richard Wentworth, who is responsible for decorating the tree with broken plates and light bulbs. It is the 17th year that the gallery has invited an artist to dress their Christmas tree. Artists who have decorated the Tate tree in previous years include Tracey Emin in 2002.',
#  '',
#  "The plain green Norway spruce is displayed in the gallery's foyer. Its light bulb adornments are dimmed, ordinary domestic ones joined together with string. The plates decorating the branches will be auctioned off for the children's charity ArtWorks. Wentworth worked as an assistant to sculptor Henry Moore in the late 1960s. His reputation as a sculptor grew in the 1980s, while he has been one of the most influential teachers during the last two decades. Wentworth is also known for his photography of mundane, everyday subjects such as a cigarette packet jammed under the wonky leg of a table."]

# %%
def spin_document(doc):
  # split the document into lines (paragraphs)
  lines = doc.split("\n")
  output = []
  for line in lines:
    if line:
      new_line = spin_line(line)
    else:
      new_line = line

    output.append(new_line)
  return "\n".join(output)

# %%
detokenizer = TreebankWordDetokenizer()

# %%
texts.iloc[0].split("\n")[2]
# Out:
# "A Christmas tree that can receive text messages has been unveiled at London's Tate Britain art gallery."

# %%
detokenizer.detokenize(word_tokenize(texts.iloc[0].split("\n")[2]))
# Out:
# "A Christmas tree that can receive text messages has been unveiled at London's Tate Britain art gallery."

# %%
def sample_word(d):
  p0 = np.random.random()
  cumulative = 0
  for t, p in d.items():
    cumulative += p
    if p0 < cumulative:
      return t
  assert(False) # should never get there

# %%
def spin_line(line):
  tokens = word_tokenize(line)
  i = 0
  output = [tokens[0]]
  while i < (len(tokens) - 2):
    t_0 = tokens[i]
    t_1 = tokens[i + 1]
    t_2 = tokens[i + 2]
    key = (t_0, t_2)
    p_dist = probs[key]
    if len(p_dist) > 1 and np.random.random() < 0.3:
      # let's replace the middle word
      middle = sample_word(p_dist)
      output.append(t_1)
      output.append("<" + middle + ">")
      output.append(t_2)


      # we won't replace the 3rd token since the middle
      # token was dependent on it
      # instead, skip ahead 2 steps
      i += 2
    else:
      # we won't replace this middle word
      output.append(t_1)
      i += 1
  # append the final token - only if there was no replacement
  if i == len(tokens) - 2:
    output.append(tokens[-1])
  return detokenizer.detokenize(output)

# %%
np.random.seed(1234)

# %%
i = np.random.choice(texts.shape[0])
doc = texts.iloc[i]
new_doc = spin_document(doc)

# %%
print(textwrap.fill(new_doc, replace_whitespace=False, fix_sentence_endings=True))
# Out:
# Fantasy book wins Hollywood deal
#
# A British author has had the film
# rights to her children <father>'s bestseller snapped up for a seven-
# figure sum, with Ridley Scott set <set> to direct <apologise>.
# Michelle Paver's Wolf Brother, a fantasy set 6,000 years ago, is <and>
# the first in <year> a planned <planned> series of six books . Film
# <The> studio Fox has bought the rights for around $4m (£2.13m) for
# Scott's company Scott Free to develop <8-1>. The director said he was
# "thrilled" with <of> the project . "Wolf Brother is an enchanting
# book," he said <said>. Paver, who lives in London <Hindi> and
# previously <also> worked as a lawyer, began writing the book
# <Children> in 1982 <1982> while studying biochemistry at Oxford
# University.
#
# She was an established author of love stories when she
# turned <accepted> the work-in-progress into a children's novel
# <career>. It was published in 2004, with Paver earning an advance of
# $5m <305m> (£2.8m <£293,000>) - the highest sum ever paid for a debut
# children's book . Wolf Brother tells the story of Torak, a <her>
# 12-year-old hunter who lives in the forest . After his father is
# killed he teams <came> up with a wolf cub and sets <sets> out to rid
# the forest <rebirth> of an evil force . Paver <He> is currently
# writing the second <best-selling> book in <from> the series . <.>
# "Michelle Paver lives and breathes the worlds she writes about, <,>"
# said a spokesman for the author . "I've told her about <for> the film
# deal but at the <the> moment she is writing the second book and <and>
# her mind is 6000 years away deep in the primeval forest."
